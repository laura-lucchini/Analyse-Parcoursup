# %% [markdown]
# ## **Projet Analyse Parcoursup**

# %% [markdown]
# ### __Analyse des données__:
#
# -  Vœux de poursuite d'études et de réorientation dans l'enseignement supérieur et réponses des établissements entre 2018 et 2025   [2022,2023,2024,2025]
# -  Propositions d'admission dans l'enseignement supérieur des élèves de terminale diplômés du baccalauréat général selon leurs enseignements de spécialité   [2022,2023,2024]

# %% [markdown]
# Sources des données:
#
# https://data.enseignementsup-recherche.gouv.fr/explore/dataset/fr-esr-cartographie_formations_parcoursup/autres_jeux/?disjunctive.tf&disjunctive.nm&disjunctive.fl&disjunctive.nmc&disjunctive.amg

# %%
#Configuration de l'environnement:

import pandas as pd
import numpy as np

# %%
# configuration des options d'affichage

pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

#pd.reset_option('display.max_columns')
#pd.reset_option('display.max_rows')

# %% [markdown]
# ### Vœux de poursuite d'études et de réorientation dans l'enseignement supérieur et réponses des établissements entre 2018 et 2025

# %%
# Liste des années
periode = ["2018", "2019", "2020", "2021", "2022", "2023", "2024", "2025"]


dataframes = []
colonnes_par_annee = {}
for annee in periode:
    fichier_csv = f"sources_brutes_csv/fr-esr-parcoursup_{annee}.csv"
    df = pd.read_csv(fichier_csv,sep=";")
    

    for colonne in df.columns:
        try:
            pd.to_numeric(df[colonne], errors='coerce')
        except ValueError:
            df[colonne] = df[colonne].astype('str')

    colonnes_par_annee[annee] = df.columns.tolist()  
    dataframes.append(df)


toutes_colonnes = []
for annee in periode:
    for colonne in colonnes_par_annee[annee]:
        if colonne not in toutes_colonnes:
            toutes_colonnes.append(colonne)


for i, annee in enumerate(periode):
    df = dataframes[i]
    for colonne in toutes_colonnes:
        if colonne not in df.columns:
            df[colonne] = np.nan
    
    df = df[toutes_colonnes]
    dataframes[i] = df


voeux = pd.concat(dataframes, ignore_index=True)



print("Aperçu du DataFrame concaténé :")
print(f"Le DataFrame concaténé contient {len(voeux)} lignes")
display(voeux.head(1))
# Out:
# Aperçu du DataFrame concaténé :
# Le DataFrame concaténé contient 104274 lignes
#    Session Code UAI de l'établissement                  Établissement  \
# 0     2018                    0692437Z  Université Jean Moulin Lyon 3
#
#   Code départemental de l’établissement Département de l’établissement  \
# 0                                    69                          Rhône
#
#   Région de l’établissement Académie de l’établissement  \
# 0      Auvergne-Rhône-Alpes                        Lyon
#
#   Filière de formation très agrégée            Filière de formation  \
# 0                           Licence  Licence - Arts-lettres-langues
#
#   Concours communs et banques d'épreuves  \
# 0                                    NaN
#
#                       Filière de formation détaillée  \
# 0  Langues, littératures & civilisations étrangèr...
#
#                  Filière de formation très détaillée  \
# 0  Langues, Littératures et Civilisations Etrangè...
#
#    Lien de la formation sur la plateforme Parcoursup  \
# 0  https://dossier.parcoursup.fr/Candidat/candida...
#
#   Coordonnées GPS de la formation  Capacité de l’établissement par formation  \
# 0            45.747754, 4.8593556                                       11.0
#
#    Effectif total des candidats pour une formation  \
# 0                                               50
#
#    Dont effectif des candidates pour une formation  \
# 0                                               34
#
#    Effectif total des candidats en phase principale  \
# 0                                                45
#
#    Dont effectif des candidats ayant postulé en internat  \
# 0                                                NaN
#
#    Effectif des candidats néo bacheliers généraux en phase principale  \
# 0                                                 34
#
#    Dont effectif des candidats boursiers néo bacheliers généraux en phase principale  \
# 0                                                  5
#
#    Effectif des candidats néo bacheliers technologiques en phase principale  \
# 0                                                  2
#
#    Dont effectif des candidats boursiers néo bacheliers technologiques en phase principale  \
# 0                                                  1
#
#    Effectif des candidats néo bacheliers professionnels en phase principale  \
# 0                                                  0
#
#    Dont effectif des candidats boursiers néo bacheliers professionnels en phase principale  \
# 0                                                  0
#
#    Effectif des autres candidats en phase principale  \
# 0                                                  9
#
#    Effectif total des candidats en phase complémentaire  \
# 0                                                  5
#
#    Effectif des candidats néo bacheliers généraux en phase complémentaire  \
# 0                                                  0
#
#    Effectif des candidats néo bacheliers technologique en phase complémentaire  \
# 0                                                  0
#
#    Effectif des candidats néo bacheliers professionnels en phase complémentaire  \
# 0                                                  0
#
#    Effectifs des autres candidats en phase complémentaire  \
# 0                                                  5
#
#    Effectif total des candidats classés par l’établissement en phase principale  \
# 0                                                 45
#
#    Effectif des candidats classés par l’établissement en phase complémentaire  \
# 0                                                  5
#
#    Effectif des candidats classés par l’établissement en internat (CPGE)  \
# 0                                                NaN
#
#    Effectif des candidats classés par l’établissement hors internat (CPGE)  \
# 0                                                NaN
#
#    Effectif des candidats néo bacheliers généraux classés par l’établissement  \
# 0                                                 34
#
#    Dont effectif des candidats boursiers néo bacheliers généraux classés par l’établissement  \
# 0                                                  5
#
#    Effectif des candidats néo bacheliers technologiques classés par l’établissement  \
# 0                                                  2
#
#    Dont effectif des candidats boursiers néo bacheliers technologiques classés par l’établissement  \
# 0                                                  1
#
#    Effectif des candidats néo bacheliers professionnels classés par l’établissement  \
# 0                                                  0
#
#    Dont effectif des candidats boursiers néo bacheliers professionnels classés par l’établissement  \
# 0                                                  0
#
#    Effectif des autres candidats classés par l’établissement  \
# 0                                                  9
#
#    Effectif total des candidats ayant reçu une proposition d’admission de la part de l’établissement  \
# 0                                                 35
#
#    Rang du dernier appelé  \
# 0                    44.0
#
#    Effectif total des candidats ayant accepté la proposition de l’établissement (admis)  \
# 0                                                  9
#
#    Dont effectif des candidates admises  \
# 0                                     6
#
#    Effectif des admis en phase principale  \
# 0                                       8
#
#    Effectif des admis en phase complémentaire  \
# 0                                           1
#
#    Dont effectif des admis en internat  \
# 0                                  NaN
#
#    Dont effectif des admis boursiers néo bacheliers  \
# 0                                                 0
#
#    Effectif des admis néo bacheliers  \
# 0                                  5
#
#    Effectif des admis néo bacheliers généraux  \
# 0                                           5
#
#    Effectif des admis néo bacheliers technologiques  \
# 0                                                 0
#
#    Effectif des admis néo bacheliers professionnels  \
# 0                                                 0
#
#    Effectif des autres candidats admis  \
# 0                                    4
#
#    Dont effectif des admis néo bacheliers sans information sur la mention au bac  \
# 0                                                  1
#
#    Dont effectif des admis néo bacheliers sans mention au bac  \
# 0                                                  4
#
#    Dont effectif des admis néo bacheliers avec mention Assez Bien au bac  \
# 0                                                  0
#
#    Dont effectif des admis néo bacheliers avec mention Bien au bac  \
# 0                                                  0
#
#    Dont effectif des admis néo bacheliers avec mention Très Bien au bac  \
# 0                                                  0
#
#    Effectif des admis néo bacheliers généraux ayant eu une mention au bac  \
# 0                                                  0
#
#    Effectif des admis néo bacheliers technologiques ayant eu une mention au bac  \
# 0                                                  0
#
#    Effectif des admis néo bacheliers professionnels ayant eu une mention au bac  \
# 0                                                  0
#
#    Dont effectif des admis issus du même établissement (BTS/CPGE)  \
# 0                                                NaN
#
#    Dont effectif des admises issues du même établissement (BTS/CPGE)  \
# 0                                                NaN
#
#    Dont effectif des admis issus de la même académie  \
# 0                                                  2
#
#    Dont effectif des admis issus de la même académie (Paris/Créteil/Versailles réunies)  \
# 0                                                  2
#
#    % d’admis dont filles  % d’admis néo bacheliers issus de la même académie  \
# 0                   66.7                                               40.0
#
#    % d’admis néo bacheliers issus de la même académie (Paris/Créteil/Versailles réunies)  \
# 0                                               40.0
#
#    % d’admis néo bacheliers issus du même établissement (BTS/CPGE)  \
# 0                                                NaN
#
#    % d’admis néo bacheliers boursiers  % d’admis néo bacheliers  \
# 0                                 0.0                      55.6
#
#    % d’admis néo bacheliers sans information sur la mention au bac  \
# 0                                               20.0
#
#    % d’admis néo bacheliers sans mention au bac  \
# 0                                          80.0
#
#    % d’admis néo bacheliers avec mention Assez Bien au bac  \
# 0                                                0.0
#
#    % d’admis néo bacheliers avec mention Bien au bac  \
# 0                                                0.0
#
#    % d’admis néo bacheliers avec mention Très Bien au bac  \
# 0                                                0.0
#
#    % d’admis néo bacheliers généraux  Dont % d’admis avec mention  \
# 0                              100.0                          0.0
#
#    % d’admis néo bacheliers technologiques  Dont % d’admis avec mention.1  \
# 0                                      0.0                            0.0
#
#    % d’admis néo bacheliers professionnels  Dont % d’admis avec mention.2  \
# 0                                      0.0                            0.0
#
#              tri  \
# 0  1_universités
#
#   Statut de l’établissement de la filière de formation (public, privé…)  \
# 0                                                NaN
#
#    Dont effectif des admis ayant reçu leur proposition d’admission à l'ouverture de la procédure principale  \
# 0                                                NaN
#
#    Dont effectif des admis ayant reçu leur proposition d’admission avant le baccalauréat  \
# 0                                                NaN
#
#    Dont effectif des admis ayant reçu leur proposition d’admission avant la fin de la procédure principale  \
# 0                                                NaN
#
#    % d’admis ayant reçu leur proposition d’admission à l'ouverture de la procédure principale  \
# 0                                                NaN
#
#    % d’admis ayant reçu leur proposition d’admission avant le baccalauréat  \
# 0                                                NaN
#
#    % d’admis ayant reçu leur proposition d’admission avant la fin de la procédure principale  \
# 0                                                NaN
#
#   Sélectivité Filière de formation détaillée.1  \
# 0         NaN                              NaN
#
#    Effectif des candidats en terminale générale ayant reçu une proposition d’admission de la part de l’établissement  \
# 0                                                NaN
#
#    Dont effectif des candidats boursiers en terminale générale ayant reçu une proposition d’admission de la part de l’établissement  \
# 0                                                NaN
#
#    Effectif des candidats en terminale technologique ayant reçu une proposition d’admission de la part de l’établissement  \
# 0                                                NaN
#
#    Dont effectif des candidats boursiers en terminale technologique ayant reçu une proposition d’admission de la part de l’établissement  \
# 0                                                NaN
#
#    Effectif des candidats en terminale professionnelle ayant reçu une proposition d’admission de la part de l’établissement  \
# 0                                                NaN
#
#    Dont effectif des candidats boursiers en terminale générale professionnelle ayant reçu une proposition d’admission de la part de l’établissement  \
# 0                                                NaN
#
#    Effectif des autres candidats ayant reçu une proposition d’admission de la part de l’établissement  \
# 0                                                NaN
#
#   Regroupement 1 effectué par les formations pour les classements  \
# 0                                                NaN
#
#   Rang du dernier appelé du groupe 1  \
# 0                                NaN
#
#   Regroupement 2 effectué par les formations pour les classements  \
# 0                                                NaN
#
#    Rang du dernier appelé du groupe 2  \
# 0                                 NaN
#
#   Regroupement 3 effectué par les formations pour les classements  \
# 0                                                NaN
#
#    Rang du dernier appelé du groupe 3  \
# 0                                 NaN
#
#   Regroupement 4 effectué par les formations pour les classements  \
# 0                                                NaN
#
#    Rang du dernier appelé du groupe 4  \
# 0                                 NaN
#
#   Regroupement 5 effectué par les formations pour les classements  \
# 0                                                NaN
#
#    Rang du dernier appelé du groupe 5  \
# 0                                 NaN
#
#    Indicateur Parcoursup du taux d’accès des candidats ayant postulé à la formation (ratio entre le dernier appelé et le dernier classé)  \
# 0                                                NaN
#
#    Dont taux d’accès des candidats ayant un bac professionnel ayant postulé à la formation  \
# 0                                                NaN
#
#    Dont taux d’accès des candidats ayant un bac général ayant postulé à la formation  \
# 0                                                NaN
#
#    Dont taux d’accès des candidats ayant un bac technologique ayant postulé à la formation  \
# 0                                                NaN
#
#    COD_AFF_FORM Commune de l’établissement Filière de formation.1  \
# 0           NaN                        NaN                    NaN
#
#   Filière de formation détaillée bis Concours communs et banque d'épreuves  \
# 0                                NaN                                   NaN
#
#    Dont effectif des admis néo bacheliers avec mention Très Bien avec félicitations au bac  \
# 0                                                NaN
#
#    % d’admis néo bacheliers avec mention Très Bien avec félicitations au bac  \
# 0                                                NaN
#
#    Dont % d’admis avec mention (BG)  Dont % d’admis avec mention (BT)  \
# 0                               NaN                               NaN
#
#    Dont % d’admis avec mention (BP) list_com  \
# 0                               NaN      NaN
#
#    Taux d’accès des candidats ayant postulé à la formation (ratio entre le dernier appelé et le nombre vœux PP)  \
# 0                                                NaN
#
#   etablissement_id_paysage composante_id_paysage  cod_aff_form Taux d’accès  \
# 0                      NaN                   NaN           NaN          NaN
#
#   Part des terminales générales qui étaient en position de recevoir une proposition en phase principale  \
# 0                                                NaN
#
#   Part des terminales technologiques qui étaient en position de recevoir une proposition en phase principale  \
# 0                                                NaN
#
#   Part des terminales professionnelles qui étaient en position de recevoir une proposition en phase principale
# 0                                                NaN

# %%
voeux.describe(include="all")
# Out:
#               Session Code UAI de l'établissement        Établissement  \
# count   104274.000000                      104274               104274
# unique            NaN                        4521                 4860
# top               NaN                    0673021V  Université de Lille
# freq              NaN                         718                  824
# mean      2021.696454                         NaN                  NaN
# std          2.251585                         NaN                  NaN
# min       2018.000000                         NaN                  NaN
# 25%       2020.000000                         NaN                  NaN
# 50%       2022.000000                         NaN                  NaN
# 75%       2024.000000                         NaN                  NaN
# max       2025.000000                         NaN                  NaN
#
#        Code départemental de l’établissement Département de l’établissement  \
# count                                 104202                         104271
# unique                                   209                            114
# top                                       75                          Paris
# freq                                    6351                           7349
# mean                                     NaN                            NaN
# std                                      NaN                            NaN
# min                                      NaN                            NaN
# 25%                                      NaN                            NaN
# 50%                                      NaN                            NaN
# 75%                                      NaN                            NaN
# max                                      NaN                            NaN
#
#        Région de l’établissement Académie de l’établissement  \
# count                     104086                      104274
# unique                        28                          37
# top                Ile-de-France                       Paris
# freq                       19498                        7349
# mean                         NaN                         NaN
# std                          NaN                         NaN
# min                          NaN                         NaN
# 25%                          NaN                         NaN
# 50%                          NaN                         NaN
# 75%                          NaN                         NaN
# max                          NaN                         NaN
#
#        Filière de formation très agrégée Filière de formation  \
# count                             104274               104274
# unique                                13                 5449
# top                                  BTS       BTS - Services
# freq                               41966                11603
# mean                                 NaN                  NaN
# std                                  NaN                  NaN
# min                                  NaN                  NaN
# 25%                                  NaN                  NaN
# 50%                                  NaN                  NaN
# 75%                                  NaN                  NaN
# max                                  NaN                  NaN
#
#        Concours communs et banques d'épreuves  \
# count                                    1139
# unique                                     71
# top                  Concours Puissance Alpha
# freq                                      294
# mean                                      NaN
# std                                       NaN
# min                                       NaN
# 25%                                       NaN
# 50%                                       NaN
# 75%                                       NaN
# max                                       NaN
#
#                            Filière de formation détaillée  \
# count                                              104274
# unique                                              23827
# top     Langues, littératures & civilisations étrangèr...
# freq                                                  823
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        Filière de formation très détaillée  \
# count                                29275
# unique                                7061
# top                                Anglais
# freq                                   322
# mean                                   NaN
# std                                    NaN
# min                                    NaN
# 25%                                    NaN
# 50%                                    NaN
# 75%                                    NaN
# max                                    NaN
#
#         Lien de la formation sur la plateforme Parcoursup  \
# count                                              101759
# unique                                              64929
# top     https://dossier.parcoursup.fr/Candidats/public...
# freq                                                    3
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        Coordonnées GPS de la formation  \
# count                           102761
# unique                           18679
# top                   48.8452, 2.39666
# freq                               512
# mean                               NaN
# std                                NaN
# min                                NaN
# 25%                                NaN
# 50%                                NaN
# 75%                                NaN
# max                                NaN
#
#         Capacité de l’établissement par formation  \
# count                               104254.000000
# unique                                        NaN
# top                                           NaN
# freq                                          NaN
# mean                                    57.566271
# std                                    107.584469
# min                                      0.000000
# 25%                                     20.000000
# 50%                                     32.000000
# 75%                                     52.000000
# max                                   3400.000000
#
#         Effectif total des candidats pour une formation  \
# count                                     104274.000000
# unique                                              NaN
# top                                                 NaN
# freq                                                NaN
# mean                                         853.649769
# std                                         1414.021465
# min                                            0.000000
# 25%                                          173.000000
# 50%                                          385.000000
# 75%                                          905.000000
# max                                        21829.000000
#
#         Dont effectif des candidates pour une formation  \
# count                                     104274.000000
# unique                                              NaN
# top                                                 NaN
# freq                                                NaN
# mean                                         473.471920
# std                                          901.294526
# min                                            0.000000
# 25%                                           57.000000
# 50%                                          183.000000
# 75%                                          474.000000
# max                                        14569.000000
#
#         Effectif total des candidats en phase principale  \
# count                                      104274.000000
# unique                                               NaN
# top                                                  NaN
# freq                                                 NaN
# mean                                          824.622418
# std                                          1414.202043
# min                                             0.000000
# 25%                                           153.000000
# 50%                                           354.000000
# 75%                                           859.000000
# max                                         21829.000000
#
#         Dont effectif des candidats ayant postulé en internat  \
# count                                         7435.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                           362.216947
# std                                            600.813121
# min                                              0.000000
# 25%                                             22.000000
# 50%                                            139.000000
# 75%                                            429.000000
# max                                           5821.000000
#
#         Effectif des candidats néo bacheliers généraux en phase principale  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                           425.001496
# std                                           1017.013174
# min                                              0.000000
# 25%                                             24.000000
# 50%                                             98.000000
# 75%                                            398.000000
# max                                          19884.000000
#
#         Dont effectif des candidats boursiers néo bacheliers généraux en phase principale  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            64.256938
# std                                            142.189546
# min                                              0.000000
# 25%                                              4.000000
# 50%                                             18.000000
# 75%                                             64.000000
# max                                           2411.000000
#
#         Effectif des candidats néo bacheliers technologiques en phase principale  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                           119.971153
# std                                            211.164522
# min                                              0.000000
# 25%                                             14.000000
# 50%                                             50.000000
# 75%                                            131.000000
# max                                           4920.000000
#
#         Dont effectif des candidats boursiers néo bacheliers technologiques en phase principale  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            35.073595
# std                                             69.568854
# min                                              0.000000
# 25%                                              3.000000
# 50%                                             12.000000
# 75%                                             35.000000
# max                                           1715.000000
#
#         Effectif des candidats néo bacheliers professionnels en phase principale  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            59.774949
# std                                            111.148970
# min                                              0.000000
# 25%                                              4.000000
# 50%                                             23.000000
# 75%                                             65.000000
# max                                           2047.000000
#
#         Dont effectif des candidats boursiers néo bacheliers professionnels en phase principale  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            23.261139
# std                                             48.487296
# min                                              0.000000
# 25%                                              1.000000
# 50%                                              7.000000
# 75%                                             22.000000
# max                                            890.000000
#
#         Effectif des autres candidats en phase principale  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                           219.874820
# std                                            456.226818
# min                                              0.000000
# 25%                                             33.000000
# 50%                                             88.000000
# 75%                                            217.000000
# max                                           8137.000000
#
#         Effectif total des candidats en phase complémentaire  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            29.007346
# std                                             78.729634
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              4.000000
# 75%                                             27.000000
# max                                           3532.000000
#
#         Effectif des candidats néo bacheliers généraux en phase complémentaire  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             5.667338
# std                                             22.595739
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              0.000000
# 75%                                              4.000000
# max                                           1395.000000
#
#         Effectif des candidats néo bacheliers technologique en phase complémentaire  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             4.196655
# std                                             16.207804
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              0.000000
# 75%                                              3.000000
# max                                           1090.000000
#
#         Effectif des candidats néo bacheliers professionnels en phase complémentaire  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             2.880315
# std                                              9.834868
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              0.000000
# 75%                                              2.000000
# max                                            543.000000
#
#         Effectifs des autres candidats en phase complémentaire  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            16.263038
# std                                             43.404755
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              2.000000
# 75%                                             14.000000
# max                                           1774.000000
#
#         Effectif total des candidats classés par l’établissement en phase principale  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                           588.504699
# std                                           1103.058754
# min                                              0.000000
# 25%                                             99.000000
# 50%                                            226.000000
# 75%                                            553.000000
# max                                          19404.000000
#
#         Effectif des candidats classés par l’établissement en phase complémentaire  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            12.297495
# std                                             36.766153
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              1.000000
# 75%                                              8.000000
# max                                           1828.000000
#
#         Effectif des candidats classés par l’établissement en internat (CPGE)  \
# count                                         7435.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                           188.002555
# std                                            350.163481
# min                                              0.000000
# 25%                                              0.000000
# 50%                                             71.000000
# 75%                                            213.500000
# max                                           5821.000000
#
#         Effectif des candidats classés par l’établissement hors internat (CPGE)  \
# count                                         7435.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                           527.856221
# std                                            504.669621
# min                                              0.000000
# 25%                                            198.000000
# 50%                                            385.000000
# 75%                                            689.000000
# max                                           5886.000000
#
#         Effectif des candidats néo bacheliers généraux classés par l’établissement  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                           331.411819
# std                                            783.117870
# min                                              0.000000
# 25%                                             18.000000
# 50%                                             66.000000
# 75%                                            308.000000
# max                                          14315.000000
#
#         Dont effectif des candidats boursiers néo bacheliers généraux classés par l’établissement  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            50.325690
# std                                            123.380769
# min                                              0.000000
# 25%                                              3.000000
# 50%                                             11.000000
# 75%                                             45.000000
# max                                           2411.000000
#
#         Effectif des candidats néo bacheliers technologiques classés par l’établissement  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            82.606920
# std                                            142.766062
# min                                              0.000000
# 25%                                              8.000000
# 50%                                             37.000000
# 75%                                             93.000000
# max                                           2725.000000
#
#         Dont effectif des candidats boursiers néo bacheliers technologiques classés par l’établissement  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            22.586052
# std                                             43.453805
# min                                              0.000000
# 25%                                              1.000000
# 50%                                              8.000000
# 75%                                             24.000000
# max                                            911.000000
#
#         Effectif des candidats néo bacheliers professionnels classés par l’établissement  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            40.958139
# std                                             77.212104
# min                                              0.000000
# 25%                                              1.000000
# 50%                                             14.000000
# 75%                                             47.000000
# max                                           2040.000000
#
#         Dont effectif des candidats boursiers néo bacheliers professionnels classés par l’établissement  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            15.271985
# std                                             32.350589
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              4.000000
# 75%                                             16.000000
# max                                            890.000000
#
#         Effectif des autres candidats classés par l’établissement  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                           133.527821
# std                                            345.572295
# min                                              0.000000
# 25%                                             12.000000
# 50%                                             35.000000
# 75%                                            100.000000
# max                                           7526.000000
#
#         Effectif total des candidats ayant reçu une proposition d’admission de la part de l’établissement  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                           275.729846
# std                                            441.245391
# min                                              0.000000
# 25%                                             66.000000
# 50%                                            125.000000
# 75%                                            277.000000
# max                                           8796.000000
#
#         Rang du dernier appelé  \
# count             11126.000000
# unique                     NaN
# top                        NaN
# freq                       NaN
# mean                435.682186
# std                 814.771350
# min                   1.000000
# 25%                  61.000000
# 50%                 162.000000
# 75%                 453.750000
# max               13716.000000
#
#         Effectif total des candidats ayant accepté la proposition de l’établissement (admis)  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            48.971057
# std                                             86.309556
# min                                              0.000000
# 25%                                             15.000000
# 50%                                             26.000000
# 75%                                             46.000000
# max                                           2680.000000
#
#         Dont effectif des candidates admises  \
# count                          104274.000000
# unique                                   NaN
# top                                      NaN
# freq                                     NaN
# mean                               27.191141
# std                                58.130383
# min                                 0.000000
# 25%                                 4.000000
# 50%                                13.000000
# 75%                                26.000000
# max                              1775.000000
#
#         Effectif des admis en phase principale  \
# count                            104274.000000
# unique                                     NaN
# top                                        NaN
# freq                                       NaN
# mean                                 44.300794
# std                                  81.419826
# min                                   0.000000
# 25%                                  13.000000
# 50%                                  24.000000
# 75%                                  42.000000
# max                                2447.000000
#
#         Effectif des admis en phase complémentaire  \
# count                                104274.000000
# unique                                         NaN
# top                                            NaN
# freq                                           NaN
# mean                                      4.478403
# std                                      14.045797
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.000000
# 75%                                       3.000000
# max                                    1012.000000
#
#         Dont effectif des admis en internat  \
# count                           7435.000000
# unique                                  NaN
# top                                     NaN
# freq                                    NaN
# mean                              11.402690
# std                               14.535265
# min                                0.000000
# 25%                                0.000000
# 50%                                7.000000
# 75%                               17.000000
# max                              142.000000
#
#         Dont effectif des admis boursiers néo bacheliers  \
# count                                      104274.000000
# unique                                               NaN
# top                                                  NaN
# freq                                                 NaN
# mean                                            8.354815
# std                                            15.670297
# min                                             0.000000
# 25%                                             2.000000
# 50%                                             4.000000
# 75%                                             9.000000
# max                                           454.000000
#
#         Effectif des admis néo bacheliers  \
# count                       104274.000000
# unique                                NaN
# top                                   NaN
# freq                                  NaN
# mean                            36.660587
# std                             68.703312
# min                              0.000000
# 25%                             11.000000
# 50%                             20.000000
# 75%                             35.000000
# max                           2311.000000
#
#         Effectif des admis néo bacheliers généraux  \
# count                                104274.000000
# unique                                         NaN
# top                                            NaN
# freq                                           NaN
# mean                                     24.927316
# std                                      63.208075
# min                                       0.000000
# 25%                                       2.000000
# 50%                                       6.000000
# 75%                                      24.000000
# max                                    2160.000000
#
#         Effectif des admis néo bacheliers technologiques  \
# count                                      104274.000000
# unique                                               NaN
# top                                                  NaN
# freq                                                 NaN
# mean                                            7.340142
# std                                            11.018784
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             4.000000
# 75%                                             9.000000
# max                                           181.000000
#
#         Effectif des admis néo bacheliers professionnels  \
# count                                      104274.000000
# unique                                               NaN
# top                                                  NaN
# freq                                                 NaN
# mean                                            4.393128
# std                                             5.928654
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             2.000000
# 75%                                             7.000000
# max                                           148.000000
#
#         Effectif des autres candidats admis  \
# count                         104274.000000
# unique                                  NaN
# top                                     NaN
# freq                                    NaN
# mean                              12.309722
# std                               25.967212
# min                                0.000000
# 25%                                2.000000
# 50%                                5.000000
# 75%                               11.000000
# max                             1699.000000
#
#         Dont effectif des admis néo bacheliers sans information sur la mention au bac  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             0.152751
# std                                              0.801283
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              0.000000
# 75%                                              0.000000
# max                                             52.000000
#
#         Dont effectif des admis néo bacheliers sans mention au bac  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            11.610507
# std                                             24.620028
# min                                              0.000000
# 25%                                              2.000000
# 50%                                              6.000000
# 75%                                             12.000000
# max                                            720.000000
#
#         Dont effectif des admis néo bacheliers avec mention Assez Bien au bac  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            11.953526
# std                                             23.252612
# min                                              0.000000
# 25%                                              3.000000
# 50%                                              6.000000
# 75%                                             12.000000
# max                                            581.000000
#
#         Dont effectif des admis néo bacheliers avec mention Bien au bac  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             8.459606
# std                                             19.735790
# min                                              0.000000
# 25%                                              1.000000
# 50%                                              3.000000
# 75%                                              8.000000
# max                                            597.000000
#
#         Dont effectif des admis néo bacheliers avec mention Très Bien au bac  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             4.134693
# std                                             15.492335
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              1.000000
# 75%                                              3.000000
# max                                            865.000000
#
#         Effectif des admis néo bacheliers généraux ayant eu une mention au bac  \
# count                                       104274.000000
# unique                                                NaN
# ...
# std                                             24.519360
# min                                              0.000000
# 25%                                              0.000000
# 50%                                             12.000000
# 75%                                             38.000000
# max                                            100.000000
#
#         Dont taux d’accès des candidats ayant un bac général ayant postulé à la formation  \
# count                                        24986.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            51.728808
# std                                             34.346896
# min                                              0.000000
# 25%                                             19.000000
# 50%                                             51.000000
# 75%                                             84.000000
# max                                            100.000000
#
#         Dont taux d’accès des candidats ayant un bac technologique ayant postulé à la formation  \
# count                                        24986.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            26.064076
# std                                             21.185039
# min                                              0.000000
# 25%                                              8.000000
# 50%                                             25.000000
# 75%                                             40.000000
# max                                            100.000000
#
#         COD_AFF_FORM Commune de l’établissement Filière de formation.1  \
# count   26156.000000                      69240                  69240
# unique           NaN                       1331                   3503
# top              NaN                   Toulouse         BTS - Services
# freq             NaN                       1596                  12354
# mean    14211.371884                        NaN                    NaN
# std      9355.284971                        NaN                    NaN
# min         2.000000                        NaN                    NaN
# 25%      6354.000000                        NaN                    NaN
# 50%     10906.000000                        NaN                    NaN
# 75%     23196.000000                        NaN                    NaN
# max     35054.000000                        NaN                    NaN
#
#        Filière de formation détaillée bis  \
# count                               69240
# unique                                668
# top         Formation d'ingénieur Bac + 5
# freq                                 2214
# mean                                  NaN
# std                                   NaN
# min                                   NaN
# 25%                                   NaN
# 50%                                   NaN
# 75%                                   NaN
# max                                   NaN
#
#        Concours communs et banque d'épreuves  \
# count                                   3506
# unique                                   216
# top                 Concours Puissance Alpha
# freq                                     824
# mean                                     NaN
# std                                      NaN
# min                                      NaN
# 25%                                      NaN
# 50%                                      NaN
# 75%                                      NaN
# max                                      NaN
#
#         Dont effectif des admis néo bacheliers avec mention Très Bien avec félicitations au bac  \
# count                                        69240.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             0.519743
# std                                              4.075638
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              0.000000
# 75%                                              0.000000
# max                                            275.000000
#
#         % d’admis néo bacheliers avec mention Très Bien avec félicitations au bac  \
# count                                        69014.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             0.929758
# std                                              4.569911
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              0.000000
# 75%                                              0.000000
# max                                            100.000000
#
#         Dont % d’admis avec mention (BG)  Dont % d’admis avec mention (BT)  \
# count                       69014.000000                      69014.000000
# unique                               NaN                               NaN
# top                                  NaN                               NaN
# freq                                 NaN                               NaN
# mean                           35.712056                         12.767653
# std                            35.065421                         17.289693
# min                             0.000000                          0.000000
# 25%                             0.000000                          0.000000
# 50%                            25.000000                          6.699219
# 75%                            62.000000                         20.000000
# max                           100.000000                        100.000000
#
#         Dont % d’admis avec mention (BP)  \
# count                       69014.000000
# unique                               NaN
# top                                  NaN
# freq                                 NaN
# mean                           15.647002
# std                            20.746457
# min                             0.000000
# 25%                             0.000000
# 50%                             5.000000
# 75%                            27.296875
# max                           100.000000
#
#                                       list_com  \
# count                                    69240
# unique                                       2
# top     Liste d'appel propre à cette formation
# freq                                     39191
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#         Taux d’accès des candidats ayant postulé à la formation (ratio entre le dernier appelé et le nombre vœux PP)  \
# count                                        13181.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            52.936803
# std                                             27.957189
# min                                              1.000000
# 25%                                             30.000000
# 50%                                             49.000000
# 75%                                             75.000000
# max                                            100.000000
#
#        etablissement_id_paysage composante_id_paysage  cod_aff_form  \
# count                     26053                   883  55844.000000
# unique                      497                   105           NaN
# top                       xJdyB                 Nn3jE           NaN
# freq                        690                    30           NaN
# mean                        NaN                   NaN  17319.512016
# std                         NaN                   NaN  12342.792878
# min                         NaN                   NaN      2.000000
# 25%                         NaN                   NaN   6824.000000
# 50%                         NaN                   NaN  11953.500000
# 75%                         NaN                   NaN  26840.000000
# max                         NaN                   NaN  50456.000000
#
#         Taux d’accès  \
# count        55473.0
# unique         201.0
# top            100.0
# freq          3537.0
# mean             NaN
# std              NaN
# min              NaN
# 25%              NaN
# 50%              NaN
# 75%              NaN
# max              NaN
#
#         Part des terminales générales qui étaient en position de recevoir une proposition en phase principale  \
# count                                             55812.0
# unique                                              203.0
# top                                                 100.0
# freq                                               6340.0
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         Part des terminales technologiques qui étaient en position de recevoir une proposition en phase principale  \
# count                                             55812.0
# unique                                              191.0
# top                                                   0.0
# freq                                               7475.0
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         Part des terminales professionnelles qui étaient en position de recevoir une proposition en phase principale
# count                                             55812.0
# unique                                              201.0
# top                                                   0.0
# freq                                              13173.0
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %%
voeux.shape
# Out:
# (104274, 134)

# %%
valeurs_manquantes = pd.DataFrame({'valeurs manquantes' : voeux.isna().sum()})
valeurs_manquantes = valeurs_manquantes.sort_values(by= 'valeurs manquantes', ascending = False)
valeurs_manquantes.head(25)
# Out:
#                                                     valeurs manquantes
# Regroupement 5 effectué par les formations pour...              104260
# Rang du dernier appelé du groupe 4                              104260
# Rang du dernier appelé du groupe 5                              104260
# Regroupement 4 effectué par les formations pour...              104260
# composante_id_paysage                                           103391
# Concours communs et banques d'épreuves                          103135
# Concours communs et banque d'épreuves                           100768
# Effectif des candidats classés par l’établissem...               96839
# Dont effectif des admis en internat                              96839
# Dont effectif des candidats ayant postulé en in...               96839
# Effectif des candidats classés par l’établissem...               96839
# Rang du dernier appelé                                           93148
# Indicateur Parcoursup du taux d’accès des candi...               91748
# Filière de formation détaillée.1                                 91514
# Taux d’accès des candidats ayant postulé à la f...               91093
# Regroupement 3 effectué par les formations pour...               81896
# Rang du dernier appelé du groupe 3                               81583
# Dont taux d’accès des candidats ayant un bac te...               79288
# Dont taux d’accès des candidats ayant un bac gé...               79288
# Dont taux d’accès des candidats ayant un bac pr...               79288
# etablissement_id_paysage                                         78221
# COD_AFF_FORM                                                     78118
# Filière de formation très détaillée                              74999
# Dont % d’admis avec mention.2                                    69700
# Dont % d’admis avec mention.1                                    69700

# %%
voeux = voeux.replace(['nd', np.inf],np.nan)
voeux = voeux.replace(r'\n', ' ', regex=True)
voeux = voeux.fillna(0)


voeux.columns = voeux.columns.str.replace('%', 'taux de', regex=False)

# %%
col_dim_etablissements=[ 
    "Code UAI de l'établissement",
    'Établissement',
    'Département de l’établissement',
    'Région de l’établissement',
    'Académie de l’établissement',
    'Coordonnées GPS de la formation',
    'Statut de l’établissement de la filière de formation (public, privé…)',
    'Commune de l’établissement'
    ]

#création de la table établissements:

dim_etablissements = voeux[col_dim_etablissements]

dim_etablissements = dim_etablissements.drop_duplicates(subset="Code UAI de l'établissement")

len(dim_etablissements)
# Out:
# 4521

# %%
dim_etablissements.dtypes
# Out:
# Code UAI de l'établissement                                              object
# Établissement                                                            object
# Département de l’établissement                                           object
# Région de l’établissement                                                object
# Académie de l’établissement                                              object
# Coordonnées GPS de la formation                                          object
# Statut de l’établissement de la filière de formation (public, privé…)    object
# Commune de l’établissement                                               object
# dtype: object

# %%
dim_etablissements["Région de l’établissement"].unique()
# Out:
# array(['Auvergne-Rhône-Alpes', 'Ile-de-France', 'Occitanie', 'Grand Est',
#        'Bourgogne-Franche-Comté', 'Centre-Val de Loire',
#        'Hauts-de-France', "Provence Alpes Côte d'Azur",
#        'Nouvelle-Aquitaine', 'Pays de la Loire', 'Normandie', 'Bretagne',
#        'Polynésie française', 'Martinique', 'Mayotte', 'La Réunion',
#        'Guadeloupe', 'Guyane', 'Corse', 'Etranger', 'Saint-Martin',
#        'Provence-Alpes-Côte d’Azur', 'Nouvelle Aquitaine', 'Grand-Est',
#        'Pays-de-la-Loire', "Provence-Alpes-Côte d'Azur", 'Centre', 0,
#        'Réunion'], dtype=object)

# %%
dim_etablissements[dim_etablissements["Région de l’établissement"] == 0]
# Out:
#        Code UAI de l'établissement  \
# 95615                     1340047Y
# 97392                     1120002U
# 101431                    3220013P
# 103181                    9830707B
# 103187                    3220014R
# 103226                    9840521U
#
#                                             Établissement  \
# 95615                 ESSCA School of Management - Malaga
# 97392               ESSCA School of Management - Budapest
# 101431  EIME - Ecole Internationale du Management et d...
# 103181  Département Sciences et techniques de l'univer...
# 103187  South Champagne Business School (Y Schools) - ...
# 103226                  Ecole Polytechnique Universitaire
#
#        Département de l’établissement Région de l’établissement  \
# 95615                        Etranger                         0
# 97392                        Etranger                         0
# 101431                       Etranger                         0
# 103181             Nouvelle-Calédonie                         0
# 103187                       Etranger                         0
# 103226            Polynésie française                         0
#
#        Académie de l’établissement Coordonnées GPS de la formation  \
# 95615                     Etranger                36.7243, -4.4234
# 97392                     Etranger               47.58029, 19.0823
# 101431                    Etranger                     3.86, 11.56
# 103181          Nouvelle-Calédonie             -22.2627, 166.40335
# 103187                    Etranger                      4.03, 9.42
# 103226         Polynésie Française              17.5774, 149.60905
#
#        Statut de l’établissement de la filière de formation (public, privé…)  \
# 95615                        Privé enseignement supérieur
# 97392                        Privé enseignement supérieur
# 101431                       Privé enseignement supérieur
# 103181                                             Public
# 103187                       Privé enseignement supérieur
# 103226                                             Public
#
#        Commune de l’établissement
# 95615                      Malaga
# 97392                    Budapest
# 101431                    Yaoundé
# 103181                     Nouméa
# 103187                     douala
# 103226                       Faaa

# %%
# gestion des valeurs région à 0, elles correspondent à des campus hors métropole 

dim_etablissements["Région de l’établissement"] = dim_etablissements["Région de l’établissement"].replace(0,"Campus hors métropole")

dim_etablissements["Région de l’établissement"].unique()
# Out:
# array(['Auvergne-Rhône-Alpes', 'Ile-de-France', 'Occitanie', 'Grand Est',
#        'Bourgogne-Franche-Comté', 'Centre-Val de Loire',
#        'Hauts-de-France', "Provence Alpes Côte d'Azur",
#        'Nouvelle-Aquitaine', 'Pays de la Loire', 'Normandie', 'Bretagne',
#        'Polynésie française', 'Martinique', 'Mayotte', 'La Réunion',
#        'Guadeloupe', 'Guyane', 'Corse', 'Etranger', 'Saint-Martin',
#        'Provence-Alpes-Côte d’Azur', 'Nouvelle Aquitaine', 'Grand-Est',
#        'Pays-de-la-Loire', "Provence-Alpes-Côte d'Azur", 'Centre',
#        'Campus hors métropole', 'Réunion'], dtype=object)

# %%
dim_etablissements["Commune de l’établissement"] = dim_etablissements["Commune de l’établissement"].replace(0,"Non précisé")

dim_etablissements["Commune de l’établissement"].unique()
# Out:
# array(['Non précisé', 'Nice', "Saint-Martin-d'Hères", 'Valenciennes',
#        'Bègles', 'Dijon', "Rives de l'Yon", 'Strasbourg', 'Limoges',
#        'Aurillac', 'Angers', 'Reims', 'Mulhouse', 'Versailles',
#        'Marne-la-Vallée', 'Aix-en-Provence', 'Aubervilliers',
#        'Contamine-sur-Arve', 'Elancourt', 'Tulle', 'Cayenne', 'Aniche',
#        'Saint-Martin', 'Arcueil', 'Abbeville', "Marcy-l'Etoile",
#        'Les Abymes', 'Saint-Denis', 'Annecy', 'Saint-Chamond', 'Issoudun',
#        'Roubaix', 'Montpellier', 'Bruz', 'Lyon 5e  Arrondissement',
#        'Fort-de-France', 'Saint-Etienne', 'Puteaux', 'Saint-Nazaire',
#        'Bayonne', 'Niort', 'Verdun', 'Cambrai', 'Nancy', 'Thionville',
#        "Villeneuve-d'Ascq", 'Marseille 14e  Arrondissement',
#        'Paris  4e  Arrondissement', 'Saverne', 'Saint-Lô', 'Montrouge',
#        'Saint-Omer', 'Anglet', 'Fontainebleau', 'Bort-les-Orgues',
#        'Chenôve', 'Lognes', 'Rouen', 'Dax', 'Paris  6e  Arrondissement',
#        'Mauguio', 'Amiens', 'Lille', 'Le Havre', 'Thônes', 'Tours',
#        'Châlons-en-Champagne', 'Saint-Dié-des-Vosges', "L'Union",
#        'Voiron', 'Orléans', 'Tournon-sur-Rhône', 'Laval', 'Estaires',
#        'Roanne', 'Menton', 'RABAT-SALE', 'Six-Fours-les-Plages',
#        'Fourchambault', 'Saint-Germain-en-Laye', 'Figeac',
#        'Morsang-sur-Orge', 'Pau', 'Pantin', 'Nantes', 'Epinal',
#        'Paris 14e  Arrondissement', 'Saint-Chamas',
#        'Paris 16e  Arrondissement', 'Ploufragan', 'Tourcoing',
#        'Lyon 7e  Arrondissement', 'Poitiers', 'Bourganeuf', 'Bordeaux',
#        'Casablanca', 'Nevers', 'Maubeuge', 'Aubagne',
#        'Paris 17e  Arrondissement', 'Rousset', 'Punaauia', 'Aubière',
#        'Bergerac', 'Le Vigan', 'Uzès', "Morne-à-l'Eau", 'Le Mans',
#        'Arras', 'Laon', 'Marseille  8e  Arrondissement',
#        'Marseille 13e  Arrondissement', 'Beaupréau-en-Mauges', 'Thann',
#        'Antony', 'Gassin', 'Hérouville-Saint-Clair', 'Toulouse',
#        'Montélimar', 'Toulon', 'Maisons-Alfort', 'Saint-Malo', 'Chaumont',
#        'Marseille 15e  Arrondissement', 'Gif-sur-Yvette',
#        'Châlette-sur-Loing', 'Foulayronnes', 'Saint-Berthevin', 'Brest',
#        'Evreux', 'Draveil', 'Le Port', 'Libourne', 'Grenoble', 'Guingamp',
#        'Vaulx-en-Velin', 'Mérignac', 'Saint-Joseph', 'Azay-le-Rideau',
#        'Buxières-lès-Villiers', 'Cherbourg-en-Cotentin', 'Bron',
#        'Clermont-Ferrand', 'Moulins', "L'Arbresle", 'Rodez', 'Compiègne',
#        'Bastia', 'Rostrenen', 'Montluçon', 'Clichy',
#        'Paris 11e  Arrondissement', 'Wittenheim', 'Port-de-Bouc',
#        'Lyon 1er Arrondissement', "L'Isle-Jourdain", 'Beauvais', 'Cachan',
#        'Caen', 'Marseille  6e  Arrondissement', 'Lyon 3e  Arrondissement',
#        'Chalon-sur-Saône', 'Ecully', 'Largentière', 'Guyancourt',
#        'Paris 19e  Arrondissement', 'Sedan', 'La Plaine-des-Palmistes',
#        'Schiltigheim', 'Le Marin', 'Saint-Priest', 'La Teste-de-Buch',
#        'Paris 13e  Arrondissement', 'Besançon', 'Guilherand-Granges',
#        'Cognac', 'Le Lamentin', 'Ajaccio', 'Paris 10e  Arrondissement',
#        'Paris 20e  Arrondissement', 'La Garenne-Colombes', 'Saint-Dizier',
#        'Arpajon', 'Paris 12e  Arrondissement', 'Deauville', 'Vannes',
#        'Graulhet', 'Saint-Quentin', 'Mornand-en-Forez', 'Château-Renault',
#        'Semur-en-Auxois', 'Sète', 'Vedène', 'Rodilhan', 'Cholet', 'Hanoï',
#        'Saint-Laurent-du-Maroni', 'Saint-Yrieix-la-Perche',
#        'Paray-le-Monial', 'Oloron-Sainte-Marie', 'Aureilhan',
#        'Lesparre-Médoc', 'Villeurbanne', 'Saumur', 'Gennevilliers',
#        'Bourg-en-Bresse', 'Lunéville', 'Colomiers', 'Angoulême',
#        'Paris 18e  Arrondissement', 'Borgo', 'Saint-Etienne-du-Rouvray',
#        'Boulogne-sur-Mer', 'Dives-sur-Mer', 'Pezens',
#        'Lyon 2e  Arrondissement', 'Pontoise', 'Rennes', 'Grande-Synthe',
#        'Tarbes', 'Mont-Saint-Martin', 'Marseille  7e  Arrondissement',
#        'Rive-de-Gier', 'Rezé', 'Guipavas', 'Valence', 'Pont-Audemer',
#        'Dole', 'Paris  5e  Arrondissement', 'Courbevoie', 'Cergy',
#        'Dublin', 'Auxerre', 'Hanches', 'Quimper', 'Orthez', 'Bandraboua',
#        'Saint-Ouen-sur-Seine', 'Lorient', 'Bernay', 'Tonneins',
#        'Basse-Terre', 'Alès', 'Oignies', 'Avignon', 'Montbéliard',
#        'Ploërmel', 'Papeete', 'Bourges', 'Le Coteau', 'Dunkerque',
#        'La Rochelle', 'Concarneau', 'Romilly-sur-Seine',
#        'Evry-Courcouronnes', 'Plescop', 'Valbonne', 'Le Sequestre',
#        'Metz', 'Etiolles', 'Argenteuil', 'Sarrebourg', 'Marseille',
#        'Saint-Martin-Boulogne', 'Paris 15e  Arrondissement', 'Calais',
#        'Le Petit-Quevilly', 'Doullens', 'Gragnague', 'Offranville',
#        'Nîmes', 'Châteaubriant', 'La Motte-Servolex', 'Le Bourget-du-Lac',
#        'Colmar', 'Saint-Gaudens', 'Saint-Sébastien-de-Morsent',
#        'Montauban', 'Castelnau-le-Lez', 'Châteauneuf-sur-Isère', 'Pessac',
#        'Draguignan', 'Digne-les-Bains', 'Talence', 'La Boisse', 'Béziers',
#        'Avion', 'Lons-le-Saunier', 'Changé', 'Lannion',
#        'Paris  9e  Arrondissement', 'Montargis', 'Bondy',
#        'Sarrola-Carcopino', 'Châteaudun', 'Riom', 'Marquise',
#        "Les Sables-d'Olonne", 'Belfort', 'Corbeil-Essonnes', 'Pontivy',
#        'Bétheny', 'Brive-la-Gaillarde', "Tain-l'Hermitage", 'Pointel',
#        'Gap', 'Gradignan', 'Lillers', 'Andrézieux-Bouthéon',
#        'Lyon 9e  Arrondissement', 'Blois', 'Marcq-en-Baroeul',
#        'Saint-Vaury', 'Roscoff', 'Bellignat', 'Lormont', 'Mont-de-Marsan',
#        'Saint-Avé', 'Liévin', 'Choisy-le-Roi', 'Carcassonne',
#        'Roussillon', 'Vandoeuvre-lès-Nancy', 'Montigny-le-Bretonneux',
#        'Douarnenez', 'Palaiseau', 'Redon', 'Savigny-le-Temple', 'Montech',
#        'Béthune', 'Villelongue-dels-Monts', 'Le Kremlin-Bicêtre',
#        'Bruges', 'Morlaix', 'Cernay', 'Bobigny', 'Meylan', 'Osny',
#        'Beaugency', 'Malaga', 'Villers-lès-Nancy', 'Saint-André',
#        'Baie-Mahault', 'Budapest', 'Langon', 'Marguerittes', 'Aubenas',
#        'Condé-en-Normandie', 'La Couronne', 'Eragny', 'Sommières',
#        'Sucy-en-Brie', 'Meaux', 'Arles', 'Marseille  2e  Arrondissement',
#        'Savy-Berlette', 'Moissac', 'Matoury', 'Yaoundé', 'Surgères',
#        'Nouméa', 'Loches', 'douala', 'Mirecourt', 'Faaa',
#        'La Jaille-Yvon', 'Marseille  3e  Arrondissement'], dtype=object)

# %%
dim_etablissements["Statut de l’établissement de la filière de formation (public, privé…)"] = dim_etablissements["Statut de l’établissement de la filière de formation (public, privé…)"].replace(0,"Non précisé")

dim_etablissements["Statut de l’établissement de la filière de formation (public, privé…)"].unique()
# Out:
# array(['Non précisé', 'Privé', 'Public', 'Privé enseignement supérieur',
#        'Privé hors contrat', "Privé sous contrat d'association"],
#       dtype=object)

# %%
dim_etablissements.dtypes
# Out:
# Code UAI de l'établissement                                              object
# Établissement                                                            object
# Département de l’établissement                                           object
# Région de l’établissement                                                object
# Académie de l’établissement                                              object
# Coordonnées GPS de la formation                                          object
# Statut de l’établissement de la filière de formation (public, privé…)    object
# Commune de l’établissement                                               object
# dtype: object

# %%
col_a_garder = ['Session',
"Code UAI de l'établissement",
'Filière de formation très agrégée',
'Filière de formation',
"Concours communs et banques d'épreuves",
'Filière de formation détaillée',
'Filière de formation très détaillée',
'Lien de la formation sur la plateforme Parcoursup',
'Coordonnées GPS de la formation',
"Capacité de l’établissement par formation",
'Effectif total des candidats pour une formation',
'Dont effectif des candidates pour une formation',
'Effectif total des candidats en phase principale',
'Effectif des candidats néo bacheliers généraux en phase principale',
'Dont effectif des candidats boursiers néo bacheliers généraux en phase principale',
'Effectif des candidats néo bacheliers technologiques en phase principale',
'Dont effectif des candidats boursiers néo bacheliers technologiques en phase principale',
'Effectif des candidats néo bacheliers professionnels en phase principale',
'Dont effectif des candidats boursiers néo bacheliers professionnels en phase principale',
'Effectif des autres candidats en phase principale',
'Effectif total des candidats en phase complémentaire',
'Effectif des candidats néo bacheliers généraux en phase complémentaire',
'Effectif des candidats néo bacheliers technologique en phase complémentaire',
'Effectif des candidats néo bacheliers professionnels en phase complémentaire',
'Effectifs des autres candidats en phase complémentaire',
"Effectif total des candidats classés par l’établissement en phase principale",
'Effectif des candidats classés par l’établissement en phase complémentaire',
"Effectif des candidats néo bacheliers généraux classés par l’établissement",
"Dont effectif des candidats boursiers néo bacheliers généraux classés par l’établissement",
"Effectif des candidats néo bacheliers technologiques classés par l’établissement",
"Dont effectif des candidats boursiers néo bacheliers technologiques classés par l’établissement",
"Effectif des candidats néo bacheliers professionnels classés par l’établissement",
"Dont effectif des candidats boursiers néo bacheliers professionnels classés par l’établissement",
"Effectif des autres candidats classés par l’établissement",
"Effectif total des candidats ayant reçu une proposition d’admission de la part de l’établissement",
'Rang du dernier appelé',
"Effectif total des candidats ayant accepté la proposition de l’établissement (admis)",
'Dont effectif des candidates admises',
'Effectif des admis en phase principale',
'Effectif des admis en phase complémentaire',
'Dont effectif des admis boursiers néo bacheliers',
'Effectif des admis néo bacheliers',
'Effectif des admis néo bacheliers généraux',
'Effectif des admis néo bacheliers technologiques',
'Effectif des admis néo bacheliers professionnels',
'Effectif des autres candidats admis',
'Dont effectif des admis néo bacheliers sans information sur la mention au bac',
'Dont effectif des admis néo bacheliers sans mention au bac',
'Dont effectif des admis néo bacheliers avec mention Assez Bien au bac',
'Dont effectif des admis néo bacheliers avec mention Bien au bac',
'Dont effectif des admis néo bacheliers avec mention Très Bien au bac',
'Effectif des admis néo bacheliers généraux ayant eu une mention au bac',
'Effectif des admis néo bacheliers technologiques ayant eu une mention au bac',
'Effectif des admis néo bacheliers professionnels ayant eu une mention au bac',
'tri',
"Dont effectif des admis ayant reçu leur proposition d’admission à l'ouverture de la procédure principale",
"Dont effectif des admis ayant reçu leur proposition d’admission avant le baccalauréat",
"Dont effectif des admis ayant reçu leur proposition d’admission avant la fin de la procédure principale",
'Sélectivité',
'Filière de formation détaillée.1',
"Effectif des candidats en terminale générale ayant reçu une proposition d’admission de la part de l’établissement",
"Dont effectif des candidats boursiers en terminale générale ayant reçu une proposition d’admission de la part de l’établissement",
"Effectif des candidats en terminale technologique ayant reçu une proposition d’admission de la part de l’établissement",
"Dont effectif des candidats boursiers en terminale technologique ayant reçu une proposition d’admission de la part de l’établissement",
"Effectif des candidats en terminale professionnelle ayant reçu une proposition d’admission de la part de l’établissement",
"Dont effectif des candidats boursiers en terminale générale professionnelle ayant reçu une proposition d’admission de la part de l’établissement",
"Effectif des autres candidats ayant reçu une proposition d’admission de la part de l’établissement",
'Regroupement 1 effectué par les formations pour les classements',
'Rang du dernier appelé du groupe 1',
'Regroupement 2 effectué par les formations pour les classements',
'Rang du dernier appelé du groupe 2',
'Regroupement 3 effectué par les formations pour les classements',
'Rang du dernier appelé du groupe 3',
'Regroupement 4 effectué par les formations pour les classements',
'Rang du dernier appelé du groupe 4',
'Regroupement 5 effectué par les formations pour les classements',
'Rang du dernier appelé du groupe 5',
"Indicateur Parcoursup du taux d’accès des candidats ayant postulé à la formation (ratio entre le dernier appelé et le dernier classé)",
'Dont taux d’accès des candidats ayant un bac professionnel ayant postulé à la formation',
'Dont taux d’accès des candidats ayant un bac général ayant postulé à la formation',
'Dont taux d’accès des candidats ayant un bac technologique ayant postulé à la formation',
'COD_AFF_FORM',
'Filière de formation.1',
'Filière de formation détaillée bis',
"Concours communs et banque d'épreuves",
'Dont effectif des admis néo bacheliers avec mention Très Bien avec félicitations au bac',
'list_com',
"Taux d’accès des candidats ayant postulé à la formation (ratio entre le dernier appelé et le nombre vœux PP)",
'cod_aff_form',
"Taux d’accès",
"Académie de l’établissement"
]

voeux = voeux[col_a_garder]

# %%
voeux.shape
# Out:
# (104274, 91)

# %%
voeux.describe(include = "all")
# Out:
#               Session Code UAI de l'établissement  \
# count   104274.000000                      104274
# unique            NaN                        4521
# top               NaN                    0673021V
# freq              NaN                         718
# mean      2021.696454                         NaN
# std          2.251585                         NaN
# min       2018.000000                         NaN
# 25%       2020.000000                         NaN
# 50%       2022.000000                         NaN
# 75%       2024.000000                         NaN
# max       2025.000000                         NaN
#
#        Filière de formation très agrégée Filière de formation  \
# count                             104274               104274
# unique                                13                 5449
# top                                  BTS       BTS - Services
# freq                               41966                11603
# mean                                 NaN                  NaN
# std                                  NaN                  NaN
# min                                  NaN                  NaN
# 25%                                  NaN                  NaN
# 50%                                  NaN                  NaN
# 75%                                  NaN                  NaN
# max                                  NaN                  NaN
#
#         Concours communs et banques d'épreuves  \
# count                                 104274.0
# unique                                    72.0
# top                                        0.0
# freq                                  103135.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#                            Filière de formation détaillée  \
# count                                              104274
# unique                                              23827
# top     Langues, littératures & civilisations étrangèr...
# freq                                                  823
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         Filière de formation très détaillée  \
# count                              104274.0
# unique                               7062.0
# top                                     0.0
# freq                                74999.0
# mean                                    NaN
# std                                     NaN
# min                                     NaN
# 25%                                     NaN
# 50%                                     NaN
# 75%                                     NaN
# max                                     NaN
#
#         Lien de la formation sur la plateforme Parcoursup  \
# count                                            104274.0
# unique                                            64930.0
# top                                                   0.0
# freq                                               2515.0
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         Coordonnées GPS de la formation  \
# count                          104274.0
# unique                          18680.0
# top                                 0.0
# freq                             1513.0
# mean                                NaN
# std                                 NaN
# min                                 NaN
# 25%                                 NaN
# 50%                                 NaN
# 75%                                 NaN
# max                                 NaN
#
#         Capacité de l’établissement par formation  \
# count                               104274.000000
# unique                                        NaN
# top                                           NaN
# freq                                          NaN
# mean                                    57.555229
# std                                    107.577105
# min                                      0.000000
# 25%                                     20.000000
# 50%                                     32.000000
# 75%                                     52.000000
# max                                   3400.000000
#
#         Effectif total des candidats pour une formation  \
# count                                     104274.000000
# unique                                              NaN
# top                                                 NaN
# freq                                                NaN
# mean                                         853.649769
# std                                         1414.021465
# min                                            0.000000
# 25%                                          173.000000
# 50%                                          385.000000
# 75%                                          905.000000
# max                                        21829.000000
#
#         Dont effectif des candidates pour une formation  \
# count                                     104274.000000
# unique                                              NaN
# top                                                 NaN
# freq                                                NaN
# mean                                         473.471920
# std                                          901.294526
# min                                            0.000000
# 25%                                           57.000000
# 50%                                          183.000000
# 75%                                          474.000000
# max                                        14569.000000
#
#         Effectif total des candidats en phase principale  \
# count                                      104274.000000
# unique                                               NaN
# top                                                  NaN
# freq                                                 NaN
# mean                                          824.622418
# std                                          1414.202043
# min                                             0.000000
# 25%                                           153.000000
# 50%                                           354.000000
# 75%                                           859.000000
# max                                         21829.000000
#
#         Effectif des candidats néo bacheliers généraux en phase principale  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                           425.001496
# std                                           1017.013174
# min                                              0.000000
# 25%                                             24.000000
# 50%                                             98.000000
# 75%                                            398.000000
# max                                          19884.000000
#
#         Dont effectif des candidats boursiers néo bacheliers généraux en phase principale  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            64.256938
# std                                            142.189546
# min                                              0.000000
# 25%                                              4.000000
# 50%                                             18.000000
# 75%                                             64.000000
# max                                           2411.000000
#
#         Effectif des candidats néo bacheliers technologiques en phase principale  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                           119.971153
# std                                            211.164522
# min                                              0.000000
# 25%                                             14.000000
# 50%                                             50.000000
# 75%                                            131.000000
# max                                           4920.000000
#
#         Dont effectif des candidats boursiers néo bacheliers technologiques en phase principale  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            35.073595
# std                                             69.568854
# min                                              0.000000
# 25%                                              3.000000
# 50%                                             12.000000
# 75%                                             35.000000
# max                                           1715.000000
#
#         Effectif des candidats néo bacheliers professionnels en phase principale  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            59.774949
# std                                            111.148970
# min                                              0.000000
# 25%                                              4.000000
# 50%                                             23.000000
# 75%                                             65.000000
# max                                           2047.000000
#
#         Dont effectif des candidats boursiers néo bacheliers professionnels en phase principale  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            23.261139
# std                                             48.487296
# min                                              0.000000
# 25%                                              1.000000
# 50%                                              7.000000
# 75%                                             22.000000
# max                                            890.000000
#
#         Effectif des autres candidats en phase principale  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                           219.874820
# std                                            456.226818
# min                                              0.000000
# 25%                                             33.000000
# 50%                                             88.000000
# 75%                                            217.000000
# max                                           8137.000000
#
#         Effectif total des candidats en phase complémentaire  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            29.007346
# std                                             78.729634
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              4.000000
# 75%                                             27.000000
# max                                           3532.000000
#
#         Effectif des candidats néo bacheliers généraux en phase complémentaire  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             5.667338
# std                                             22.595739
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              0.000000
# 75%                                              4.000000
# max                                           1395.000000
#
#         Effectif des candidats néo bacheliers technologique en phase complémentaire  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             4.196655
# std                                             16.207804
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              0.000000
# 75%                                              3.000000
# max                                           1090.000000
#
#         Effectif des candidats néo bacheliers professionnels en phase complémentaire  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             2.880315
# std                                              9.834868
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              0.000000
# 75%                                              2.000000
# max                                            543.000000
#
#         Effectifs des autres candidats en phase complémentaire  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            16.263038
# std                                             43.404755
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              2.000000
# 75%                                             14.000000
# max                                           1774.000000
#
#         Effectif total des candidats classés par l’établissement en phase principale  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                           588.504699
# std                                           1103.058754
# min                                              0.000000
# 25%                                             99.000000
# 50%                                            226.000000
# 75%                                            553.000000
# max                                          19404.000000
#
#         Effectif des candidats classés par l’établissement en phase complémentaire  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            12.297495
# std                                             36.766153
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              1.000000
# 75%                                              8.000000
# max                                           1828.000000
#
#         Effectif des candidats néo bacheliers généraux classés par l’établissement  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                           331.411819
# std                                            783.117870
# min                                              0.000000
# 25%                                             18.000000
# 50%                                             66.000000
# 75%                                            308.000000
# max                                          14315.000000
#
#         Dont effectif des candidats boursiers néo bacheliers généraux classés par l’établissement  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            50.325690
# std                                            123.380769
# min                                              0.000000
# 25%                                              3.000000
# 50%                                             11.000000
# 75%                                             45.000000
# max                                           2411.000000
#
#         Effectif des candidats néo bacheliers technologiques classés par l’établissement  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            82.606920
# std                                            142.766062
# min                                              0.000000
# 25%                                              8.000000
# 50%                                             37.000000
# 75%                                             93.000000
# max                                           2725.000000
#
#         Dont effectif des candidats boursiers néo bacheliers technologiques classés par l’établissement  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            22.586052
# std                                             43.453805
# min                                              0.000000
# 25%                                              1.000000
# 50%                                              8.000000
# 75%                                             24.000000
# max                                            911.000000
#
#         Effectif des candidats néo bacheliers professionnels classés par l’établissement  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            40.958139
# std                                             77.212104
# min                                              0.000000
# 25%                                              1.000000
# 50%                                             14.000000
# 75%                                             47.000000
# max                                           2040.000000
#
#         Dont effectif des candidats boursiers néo bacheliers professionnels classés par l’établissement  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            15.271985
# std                                             32.350589
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              4.000000
# 75%                                             16.000000
# max                                            890.000000
#
#         Effectif des autres candidats classés par l’établissement  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                           133.527821
# std                                            345.572295
# min                                              0.000000
# 25%                                             12.000000
# 50%                                             35.000000
# 75%                                            100.000000
# max                                           7526.000000
#
#         Effectif total des candidats ayant reçu une proposition d’admission de la part de l’établissement  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                           275.729846
# std                                            441.245391
# min                                              0.000000
# 25%                                             66.000000
# 50%                                            125.000000
# 75%                                            277.000000
# max                                           8796.000000
#
#         Rang du dernier appelé  \
# count            104274.000000
# unique                     NaN
# top                        NaN
# freq                       NaN
# mean                 46.487140
# std                 298.194348
# min                   0.000000
# 25%                   0.000000
# 50%                   0.000000
# 75%                   0.000000
# max               13716.000000
#
#         Effectif total des candidats ayant accepté la proposition de l’établissement (admis)  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            48.971057
# std                                             86.309556
# min                                              0.000000
# 25%                                             15.000000
# 50%                                             26.000000
# 75%                                             46.000000
# max                                           2680.000000
#
#         Dont effectif des candidates admises  \
# count                          104274.000000
# unique                                   NaN
# top                                      NaN
# freq                                     NaN
# mean                               27.191141
# std                                58.130383
# min                                 0.000000
# 25%                                 4.000000
# 50%                                13.000000
# 75%                                26.000000
# max                              1775.000000
#
#         Effectif des admis en phase principale  \
# count                            104274.000000
# unique                                     NaN
# top                                        NaN
# freq                                       NaN
# mean                                 44.300794
# std                                  81.419826
# min                                   0.000000
# 25%                                  13.000000
# 50%                                  24.000000
# 75%                                  42.000000
# max                                2447.000000
#
#         Effectif des admis en phase complémentaire  \
# count                                104274.000000
# unique                                         NaN
# top                                            NaN
# freq                                           NaN
# mean                                      4.478403
# std                                      14.045797
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.000000
# 75%                                       3.000000
# max                                    1012.000000
#
#         Dont effectif des admis boursiers néo bacheliers  \
# count                                      104274.000000
# unique                                               NaN
# top                                                  NaN
# freq                                                 NaN
# mean                                            8.354815
# std                                            15.670297
# min                                             0.000000
# 25%                                             2.000000
# 50%                                             4.000000
# 75%                                             9.000000
# max                                           454.000000
#
#         Effectif des admis néo bacheliers  \
# count                       104274.000000
# unique                                NaN
# top                                   NaN
# freq                                  NaN
# mean                            36.660587
# std                             68.703312
# min                              0.000000
# 25%                             11.000000
# 50%                             20.000000
# 75%                             35.000000
# max                           2311.000000
#
#         Effectif des admis néo bacheliers généraux  \
# count                                104274.000000
# unique                                         NaN
# top                                            NaN
# freq                                           NaN
# mean                                     24.927316
# std                                      63.208075
# min                                       0.000000
# 25%                                       2.000000
# 50%                                       6.000000
# 75%                                      24.000000
# max                                    2160.000000
#
#         Effectif des admis néo bacheliers technologiques  \
# count                                      104274.000000
# unique                                               NaN
# top                                                  NaN
# freq                                                 NaN
# mean                                            7.340142
# std                                            11.018784
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             4.000000
# 75%                                             9.000000
# max                                           181.000000
#
#         Effectif des admis néo bacheliers professionnels  \
# count                                      104274.000000
# unique                                               NaN
# top                                                  NaN
# freq                                                 NaN
# mean                                            4.393128
# std                                             5.928654
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             2.000000
# 75%                                             7.000000
# max                                           148.000000
#
#         Effectif des autres candidats admis  \
# count                         104274.000000
# unique                                  NaN
# top                                     NaN
# freq                                    NaN
# mean                              12.309722
# std                               25.967212
# min                                0.000000
# 25%                                2.000000
# 50%                                5.000000
# 75%                               11.000000
# max                             1699.000000
#
#         Dont effectif des admis néo bacheliers sans information sur la mention au bac  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             0.152751
# std                                              0.801283
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              0.000000
# 75%                                              0.000000
# max                                             52.000000
#
#         Dont effectif des admis néo bacheliers sans mention au bac  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            11.610507
# std                                             24.620028
# min                                              0.000000
# 25%                                              2.000000
# 50%                                              6.000000
# 75%                                             12.000000
# max                                            720.000000
#
#         Dont effectif des admis néo bacheliers avec mention Assez Bien au bac  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            11.953526
# std                                             23.252612
# min                                              0.000000
# 25%                                              3.000000
# 50%                                              6.000000
# 75%                                             12.000000
# max                                            581.000000
#
#         Dont effectif des admis néo bacheliers avec mention Bien au bac  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             8.459606
# std                                             19.735790
# min                                              0.000000
# 25%                                              1.000000
# 50%                                              3.000000
# 75%                                              8.000000
# max                                            597.000000
#
#         Dont effectif des admis néo bacheliers avec mention Très Bien au bac  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             4.134693
# std                                             15.492335
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              1.000000
# 75%                                              3.000000
# max                                            865.000000
#
#         Effectif des admis néo bacheliers généraux ayant eu une mention au bac  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            17.755183
# std                                             48.457973
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              3.000000
# 75%                                             17.000000
# max                                           1582.000000
#
#         Effectif des admis néo bacheliers technologiques ayant eu une mention au bac  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             4.108704
# std                                              7.691140
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              2.000000
# 75%                                              5.000000
# max                                            167.000000
#
#         Effectif des admis néo bacheliers professionnels ayant eu une mention au bac  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             3.029058
# std                                              4.311524
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              1.000000
# 75%                                              5.000000
# max                                             69.000000
#
#              tri  \
# count     104274
# unique         4
# top     2_Lycées
# freq       49401
# mean         NaN
# std          NaN
# min          NaN
# 25%          NaN
# 50%          NaN
# 75%          NaN
# max          NaN
#
#         Dont effectif des admis ayant reçu leur proposition d’admission à l'ouverture de la procédure principale  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            13.704030
# std                                             35.796956
# min                                              0.000000
# 25%                                              1.000000
# 50%                                              5.000000
# 75%                                             12.000000
# max                                           2177.000000
#
#         Dont effectif des admis ayant reçu leur proposition d’admission avant le baccalauréat  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            33.894931
# std                                             66.881773
# min                                              0.000000
# ...
# max                                                   NaN
#
#         Rang du dernier appelé du groupe 2  \
# count                        104274.000000
# unique                                 NaN
# top                                    NaN
# freq                                   NaN
# mean                             25.240587
# std                              75.456751
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                              26.000000
# max                            8430.000000
#
#         Regroupement 3 effectué par les formations pour les classements  \
# count                                            104274.0
# unique                                               14.0
# top                                                   0.0
# freq                                              81896.0
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         Rang du dernier appelé du groupe 3  \
# count                        104274.000000
# unique                                 NaN
# top                                    NaN
# freq                                   NaN
# mean                             15.019123
# std                              60.774831
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                           10044.000000
#
#         Regroupement 4 effectué par les formations pour les classements  \
# count                                            104274.0
# unique                                                6.0
# top                                                   0.0
# freq                                             104260.0
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         Rang du dernier appelé du groupe 4  \
# count                        104274.000000
# unique                                 NaN
# top                                    NaN
# freq                                   NaN
# mean                              0.200491
# std                              32.704499
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                            9066.000000
#
#         Regroupement 5 effectué par les formations pour les classements  \
# count                                            104274.0
# unique                                                6.0
# top                                                   0.0
# freq                                             104260.0
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         Rang du dernier appelé du groupe 5  \
# count                        104274.000000
# unique                                 NaN
# top                                    NaN
# freq                                   NaN
# mean                              0.205689
# std                              24.821430
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                            5040.000000
#
#         Indicateur Parcoursup du taux d’accès des candidats ayant postulé à la formation (ratio entre le dernier appelé et le dernier classé)  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             6.270892
# std                                             19.523159
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              0.000000
# 75%                                              0.000000
# max                                            100.000000
#
#         Dont taux d’accès des candidats ayant un bac professionnel ayant postulé à la formation  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             5.169572
# std                                             15.128108
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              0.000000
# 75%                                              0.000000
# max                                            100.000000
#
#         Dont taux d’accès des candidats ayant un bac général ayant postulé à la formation  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            12.395190
# std                                             27.752912
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              0.000000
# 75%                                              0.000000
# max                                            100.000000
#
#         Dont taux d’accès des candidats ayant un bac technologique ayant postulé à la formation  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             6.245440
# std                                             15.209086
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              0.000000
# 75%                                              0.000000
# max                                            100.000000
#
#          COD_AFF_FORM  Filière de formation.1  \
# count   104274.000000                104274.0
# unique            NaN                  3504.0
# top               NaN                     0.0
# freq              NaN                 35034.0
# mean      3564.768236                     NaN
# std       7739.908989                     NaN
# min          0.000000                     NaN
# 25%          0.000000                     NaN
# 50%          0.000000                     NaN
# 75%         60.750000                     NaN
# max      35054.000000                     NaN
#
#         Filière de formation détaillée bis  \
# count                             104274.0
# unique                               669.0
# top                                    0.0
# freq                               35034.0
# mean                                   NaN
# std                                    NaN
# min                                    NaN
# 25%                                    NaN
# 50%                                    NaN
# 75%                                    NaN
# max                                    NaN
#
#         Concours communs et banque d'épreuves  \
# count                                104274.0
# unique                                  217.0
# top                                       0.0
# freq                                 100768.0
# mean                                      NaN
# std                                       NaN
# min                                       NaN
# 25%                                       NaN
# 50%                                       NaN
# 75%                                       NaN
# max                                       NaN
#
#         Dont effectif des admis néo bacheliers avec mention Très Bien avec félicitations au bac  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             0.345120
# std                                              3.330185
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              0.000000
# 75%                                              0.000000
# max                                            275.000000
#
#                                       list_com  \
# count                                   104274
# unique                                       3
# top     Liste d'appel propre à cette formation
# freq                                     39191
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#         Taux d’accès des candidats ayant postulé à la formation (ratio entre le dernier appelé et le nombre vœux PP)  \
# count                                       104274.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             6.691601
# std                                             20.205232
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              0.000000
# 75%                                              0.000000
# max                                            100.000000
#
#          cod_aff_form  Taux d’accès Académie de l’établissement
# count   104274.000000      104274.0                      104274
# unique            NaN         201.0                          37
# top               NaN           0.0                       Paris
# freq              NaN       49920.0                        7349
# mean      9275.474509           NaN                         NaN
# std      12498.020032           NaN                         NaN
# min          0.000000           NaN                         NaN
# 25%          0.000000           NaN                         NaN
# 50%       3114.500000           NaN                         NaN
# 75%      14686.000000           NaN                         NaN
# max      50456.000000           NaN                         NaN

# %%
for col in voeux.columns:
    if voeux[col].dtypes == 'float64':
        voeux[col] = voeux[col].astype('int')

voeux["Taux d’accès"] = voeux["Taux d’accès"].astype(int)

# %%
#harmonisation de la colonne "Sélectivité"

voeux["Sélectivité"] = voeux["Sélectivité"].replace(['formation selective'],'formation sélective')
voeux["Sélectivité"] = voeux["Sélectivité"].replace(['formation non selec'],'formation non sélective')
voeux["Sélectivité"] = voeux["Sélectivité"].replace([0],'Non précisé')

voeux["Sélectivité"].unique()
# Out:
# array(['Non précisé', 'formation sélective', 'formation non sélective'],
#       dtype=object)

# %%
voeux["Rang du dernier appelé du groupe 1"]=voeux["Rang du dernier appelé du groupe 1"].astype(int)

print(voeux["Rang du dernier appelé du groupe 1"].unique())
voeux["Rang du dernier appelé du groupe 1"].dtype
# Out:
# [   0  127  489 ... 4271 2468 5538]
# dtype('int64')

# %%
voeux["list_com"].unique()
# Out:
# array([0, "Liste d'appel propre à cette formation",
#        "Liste d'appel commune à plusieurs formations"], dtype=object)

# %%
# Modification à effectuer pour eviter les anomalies de chargement dans power BI

col_a_retraiter = ["Regroupement 1 effectué par les formations pour les classements",
    "Filière de formation détaillée.1",
    "Regroupement 2 effectué par les formations pour les classements",
    "Regroupement 3 effectué par les formations pour les classements",
    "Regroupement 4 effectué par les formations pour les classements",
    "Regroupement 5 effectué par les formations pour les classements",
    "Filière de formation.1",
    "Filière de formation détaillée bis",
    "Concours communs et banque d'épreuves",
    "list_com"
    ]


voeux[col_a_retraiter] = voeux[col_a_retraiter].replace([0],'Non précisé')

# %% [markdown]
# ### Propositions d'admission dans l'enseignement supérieur des élèves de terminale diplômés du baccalauréat général selon leurs enseignements de spécialité

# %%
dim_admissions = pd.read_csv("sources_brutes_csv/fr-esr-parcoursup-enseignements-de-specialite-bacheliers-generaux-2.csv", sep=";")


dim_admissions.head()
# Out:
#    Année du Baccalauréat                        Enseignements de spécialité  \
# 0                   2021                                            Art,Art
# 1                   2021                                            Art,Art
# 2                   2021          Art,Humanités, Littérature et Philosophie
# 3                   2021          Art,Humanités, Littérature et Philosophie
# 4                   2021  Art,Langues, littératures et cultures étrangèr...
#
#                                            Formation  \
# 0                                   Licence Histoire
# 1  Licence Mécanique, Génie mécanique, Ingénierie...
# 2     Licence Sciences et technologies industrielles
# 3                                              DEUST
# 4                                 Licence Géographie
#
#    Nombre de candidats bacheliers ayant confirmé au moins un vœu  \
# 0                                                  1
# 1                                                  0
# 2                                                 18
# 3                                                 82
# 4                                                 83
#
#    Nombre de candidats bacheliers ayant reçu au moins une proposition d'admission  \
# 0                                                0.0
# 1                                                0.0
# 2                                                9.0
# 3                                               27.0
# 4                                               39.0
#
#    Nombre de candidats bacheliers ayant accepté une proposition d'admission
# 0                                                  0
# 1                                                  0
# 2                                                  4
# 3                                                 15
# 4                                                 11

# %%
dim_admissions.dtypes
# Out:
# Année du Baccalauréat                                                               int64
# Enseignements de spécialité                                                        object
# Formation                                                                          object
# Nombre de candidats bacheliers ayant confirmé au moins un vœu                       int64
# Nombre de candidats bacheliers ayant reçu au moins une proposition d'admission    float64
# Nombre de candidats bacheliers ayant accepté une proposition d'admission            int64
# dtype: object

# %%
dim_admissions["Nombre de candidats bacheliers ayant reçu au moins une proposition d'admission"] = dim_admissions["Nombre de candidats bacheliers ayant reçu au moins une proposition d'admission"].astype(int)

dim_admissions.dtypes
# Out:
# Année du Baccalauréat                                                              int64
# Enseignements de spécialité                                                       object
# Formation                                                                         object
# Nombre de candidats bacheliers ayant confirmé au moins un vœu                      int64
# Nombre de candidats bacheliers ayant reçu au moins une proposition d'admission     int64
# Nombre de candidats bacheliers ayant accepté une proposition d'admission           int64
# dtype: object

# %%
valeurs_manquantes = pd.DataFrame({'valeurs manquantes' : dim_admissions.isna().sum()})
valeurs_manquantes = valeurs_manquantes.sort_values(by= 'valeurs manquantes', ascending = False)
valeurs_manquantes.head(25)
# Out:
#                                                     valeurs manquantes
# Année du Baccalauréat                                                0
# Enseignements de spécialité                                          0
# Formation                                                            0
# Nombre de candidats bacheliers ayant confirmé a...                   0
# Nombre de candidats bacheliers ayant reçu au mo...                   0
# Nombre de candidats bacheliers ayant accepté un...                   0

# %%
dim_admissions.describe(include="all")
# Out:
#         Année du Baccalauréat                Enseignements de spécialité  \
# count            17420.000000                                      17420
# unique                    NaN                                         76
# top                       NaN  Art,Humanités, Littérature et Philosophie
# freq                      NaN                                        260
# mean              2022.589552                                        NaN
# std                  1.117817                                        NaN
# min               2021.000000                                        NaN
# 25%               2022.000000                                        NaN
# 50%               2023.000000                                        NaN
# 75%               2024.000000                                        NaN
# max               2024.000000                                        NaN
#
#                Formation  \
# count              17420
# unique                65
# top     Licence Histoire
# freq                 268
# mean                 NaN
# std                  NaN
# min                  NaN
# 25%                  NaN
# 50%                  NaN
# 75%                  NaN
# max                  NaN
#
#         Nombre de candidats bacheliers ayant confirmé au moins un vœu  \
# count                                        17420.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                           514.460505
# std                                           2812.364045
# min                                              0.000000
# 25%                                              1.000000
# 50%                                              9.000000
# 75%                                            100.000000
# max                                          83495.000000
#
#         Nombre de candidats bacheliers ayant reçu au moins une proposition d'admission  \
# count                                        17420.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                           309.952124
# std                                           2125.829872
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              4.000000
# 75%                                             40.000000
# max                                          81107.000000
#
#         Nombre de candidats bacheliers ayant accepté une proposition d'admission
# count                                        17420.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                           151.926406
# std                                           1665.951039
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              1.000000
# 75%                                             13.000000
# max                                          75485.000000

# %%
dim_admissions.columns
# Out:
# Index(['Année du Baccalauréat', 'Enseignements de spécialité', 'Formation',
#        'Nombre de candidats bacheliers ayant confirmé au moins un vœu',
#        'Nombre de candidats bacheliers ayant reçu au moins une proposition d'admission',
#        'Nombre de candidats bacheliers ayant accepté une proposition d'admission'],
#       dtype='object')

# %%
len(dim_admissions)
# Out:
# 17420

# %%
dim_admissions['Année du Baccalauréat'].unique()
# Out:
# array([2021, 2022, 2023, 2024])

# %%
print(dim_etablissements.isna().sum())
# Out:
# Code UAI de l'établissement                                              0
# Établissement                                                            0
# Département de l’établissement                                           0
# Région de l’établissement                                                0
# Académie de l’établissement                                              0
# Coordonnées GPS de la formation                                          0
# Statut de l’établissement de la filière de formation (public, privé…)    0
# Commune de l’établissement                                               0
# dtype: int64

# %% [markdown]
# Forçage des noms de colonnes pour qu'elles apparaissent dans le bon ordre dans powerBI

# %%
voeux.columns = [f"{i}_{col}" for i, col in enumerate(voeux.columns)]

voeux.columns
# Out:
# Index(['0_Session', '1_Code UAI de l'établissement',
#        '2_Filière de formation très agrégée', '3_Filière de formation',
#        '4_Concours communs et banques d'épreuves',
#        '5_Filière de formation détaillée',
#        '6_Filière de formation très détaillée',
#        '7_Lien de la formation sur la plateforme Parcoursup',
#        '8_Coordonnées GPS de la formation',
#        '9_Capacité de l’établissement par formation',
#        '10_Effectif total des candidats pour une formation',
#        '11_Dont effectif des candidates pour une formation',
#        '12_Effectif total des candidats en phase principale',
#        '13_Effectif des candidats néo bacheliers généraux en phase principale',
#        '14_Dont effectif des candidats boursiers néo bacheliers généraux en phase principale',
#        '15_Effectif des candidats néo bacheliers technologiques en phase principale',
#        '16_Dont effectif des candidats boursiers néo bacheliers technologiques en phase principale',
#        '17_Effectif des candidats néo bacheliers professionnels en phase principale',
#        '18_Dont effectif des candidats boursiers néo bacheliers professionnels en phase principale',
#        '19_Effectif des autres candidats en phase principale',
#        '20_Effectif total des candidats en phase complémentaire',
#        '21_Effectif des candidats néo bacheliers généraux en phase complémentaire',
#        '22_Effectif des candidats néo bacheliers technologique en phase complémentaire',
#        '23_Effectif des candidats néo bacheliers professionnels en phase complémentaire',
#        '24_Effectifs des autres candidats en phase complémentaire',
#        '25_Effectif total des candidats classés par l’établissement en phase principale',
#        '26_Effectif des candidats classés par l’établissement en phase complémentaire',
#        '27_Effectif des candidats néo bacheliers généraux classés par l’établissement',
#        '28_Dont effectif des candidats boursiers néo bacheliers généraux classés par l’établissement',
#        '29_Effectif des candidats néo bacheliers technologiques classés par l’établissement',
#        '30_Dont effectif des candidats boursiers néo bacheliers technologiques classés par l’établissement',
#        '31_Effectif des candidats néo bacheliers professionnels classés par l’établissement',
#        '32_Dont effectif des candidats boursiers néo bacheliers professionnels classés par l’établissement',
#        '33_Effectif des autres candidats classés par l’établissement',
#        '34_Effectif total des candidats ayant reçu une proposition d’admission de la part de l’établissement',
#        '35_Rang du dernier appelé',
#        '36_Effectif total des candidats ayant accepté la proposition de l’établissement (admis)',
#        '37_Dont effectif des candidates admises',
#        '38_Effectif des admis en phase principale',
#        '39_Effectif des admis en phase complémentaire',
#        '40_Dont effectif des admis boursiers néo bacheliers',
#        '41_Effectif des admis néo bacheliers',
#        '42_Effectif des admis néo bacheliers généraux',
#        '43_Effectif des admis néo bacheliers technologiques',
#        '44_Effectif des admis néo bacheliers professionnels',
#        '45_Effectif des autres candidats admis',
#        '46_Dont effectif des admis néo bacheliers sans information sur la mention au bac',
#        '47_Dont effectif des admis néo bacheliers sans mention au bac',
#        '48_Dont effectif des admis néo bacheliers avec mention Assez Bien au bac',
#        '49_Dont effectif des admis néo bacheliers avec mention Bien au bac',
#        '50_Dont effectif des admis néo bacheliers avec mention Très Bien au bac',
#        '51_Effectif des admis néo bacheliers généraux ayant eu une mention au bac',
#        '52_Effectif des admis néo bacheliers technologiques ayant eu une mention au bac',
#        '53_Effectif des admis néo bacheliers professionnels ayant eu une mention au bac',
#        '54_tri',
#        '55_Dont effectif des admis ayant reçu leur proposition d’admission à l'ouverture de la procédure principale',
#        '56_Dont effectif des admis ayant reçu leur proposition d’admission avant le baccalauréat',
#        '57_Dont effectif des admis ayant reçu leur proposition d’admission avant la fin de la procédure principale',
#        '58_Sélectivité', '59_Filière de formation détaillée.1',
#        '60_Effectif des candidats en terminale générale ayant reçu une proposition d’admission de la part de l’établissement',
#        '61_Dont effectif des candidats boursiers en terminale générale ayant reçu une proposition d’admission de la part de l’établissement',
#        '62_Effectif des candidats en terminale technologique ayant reçu une proposition d’admission de la part de l’établissement',
#        '63_Dont effectif des candidats boursiers en terminale technologique ayant reçu une proposition d’admission de la part de l’établissement',
#        '64_Effectif des candidats en terminale professionnelle ayant reçu une proposition d’admission de la part de l’établissement',
#        '65_Dont effectif des candidats boursiers en terminale générale professionnelle ayant reçu une proposition d’admission de la part de l’établissement',
#        '66_Effectif des autres candidats ayant reçu une proposition d’admission de la part de l’établissement',
#        '67_Regroupement 1 effectué par les formations pour les classements',
#        '68_Rang du dernier appelé du groupe 1',
#        '69_Regroupement 2 effectué par les formations pour les classements',
#        '70_Rang du dernier appelé du groupe 2',
#        '71_Regroupement 3 effectué par les formations pour les classements',
#        '72_Rang du dernier appelé du groupe 3',
#        '73_Regroupement 4 effectué par les formations pour les classements',
#        '74_Rang du dernier appelé du groupe 4',
#        '75_Regroupement 5 effectué par les formations pour les classements',
#        '76_Rang du dernier appelé du groupe 5',
#        '77_Indicateur Parcoursup du taux d’accès des candidats ayant postulé à la formation (ratio entre le dernier appelé et le dernier classé)',
#        '78_Dont taux d’accès des candidats ayant un bac professionnel ayant postulé à la formation',
#        '79_Dont taux d’accès des candidats ayant un bac général ayant postulé à la formation',
#        '80_Dont taux d’accès des candidats ayant un bac technologique ayant postulé à la formation',
#        '81_COD_AFF_FORM', '82_Filière de formation.1',
#        '83_Filière de formation détaillée bis',
#        '84_Concours communs et banque d'épreuves',
#        '85_Dont effectif des admis néo bacheliers avec mention Très Bien avec félicitations au bac',
#        '86_list_com',
#        '87_Taux d’accès des candidats ayant postulé à la formation (ratio entre le dernier appelé et le nombre vœux PP)',
#        '88_cod_aff_form', '89_Taux d’accès', '90_Académie de l’établissement'],
#       dtype='object')

# %% [markdown]
# ### Export sous CSV  pour intégration dans Power BI

# %%
# Réduire les noms de colonnes à 128 caractères (limite sql)
#voeux.columns = [colonne[:128] for colonne in voeux.columns]

# En commentaire pour eviter d'écraser à chq lancement 
'''
dim_etablissements.to_csv("sources_clean_powerbi/dim_etablissements.csv", index=False, sep=";")

voeux.to_csv("sources_clean_powerbi/voeux.csv", index=False, sep=";") 

dim_admissions.to_csv("sources_clean_powerbi/dim_admissions.csv", index= False, sep=";")

print("les fichiers sont prêts à être intégrés dans PowerBI")'''
# Out:
# '\ndim_etablissements.to_csv("sources_clean_powerbi/dim_etablissements.csv", index=False, sep=";")\n\nvoeux.to_csv("sources_clean_powerbi/voeux.csv", index=False, sep=";") \n\ndim_admissions.to_csv("sources_clean_powerbi/dim_admissions.csv", index= False, sep=";")\n\nprint("les fichiers sont prêts à être intégrés dans PowerBI")'

# %%
list(voeux.columns)
# Out:
# ['0_Session',
#  "1_Code UAI de l'établissement",
#  '2_Filière de formation très agrégée',
#  '3_Filière de formation',
#  "4_Concours communs et banques d'épreuves",
#  '5_Filière de formation détaillée',
#  '6_Filière de formation très détaillée',
#  '7_Lien de la formation sur la plateforme Parcoursup',
#  '8_Coordonnées GPS de la formation',
#  '9_Capacité de l’établissement par formation',
#  '10_Effectif total des candidats pour une formation',
#  '11_Dont effectif des candidates pour une formation',
#  '12_Effectif total des candidats en phase principale',
#  '13_Effectif des candidats néo bacheliers généraux en phase principale',
#  '14_Dont effectif des candidats boursiers néo bacheliers généraux en phase principale',
#  '15_Effectif des candidats néo bacheliers technologiques en phase principale',
#  '16_Dont effectif des candidats boursiers néo bacheliers technologiques en phase principale',
#  '17_Effectif des candidats néo bacheliers professionnels en phase principale',
#  '18_Dont effectif des candidats boursiers néo bacheliers professionnels en phase principale',
#  '19_Effectif des autres candidats en phase principale',
#  '20_Effectif total des candidats en phase complémentaire',
#  '21_Effectif des candidats néo bacheliers généraux en phase complémentaire',
#  '22_Effectif des candidats néo bacheliers technologique en phase complémentaire',
#  '23_Effectif des candidats néo bacheliers professionnels en phase complémentaire',
#  '24_Effectifs des autres candidats en phase complémentaire',
#  '25_Effectif total des candidats classés par l’établissement en phase principale',
#  '26_Effectif des candidats classés par l’établissement en phase complémentaire',
#  '27_Effectif des candidats néo bacheliers généraux classés par l’établissement',
#  '28_Dont effectif des candidats boursiers néo bacheliers généraux classés par l’établissement',
#  '29_Effectif des candidats néo bacheliers technologiques classés par l’établissement',
#  '30_Dont effectif des candidats boursiers néo bacheliers technologiques classés par l’établissement',
#  '31_Effectif des candidats néo bacheliers professionnels classés par l’établissement',
#  '32_Dont effectif des candidats boursiers néo bacheliers professionnels classés par l’établissement',
#  '33_Effectif des autres candidats classés par l’établissement',
#  '34_Effectif total des candidats ayant reçu une proposition d’admission de la part de l’établissement',
#  '35_Rang du dernier appelé',
#  '36_Effectif total des candidats ayant accepté la proposition de l’établissement (admis)',
#  '37_Dont effectif des candidates admises',
#  '38_Effectif des admis en phase principale',
#  '39_Effectif des admis en phase complémentaire',
#  '40_Dont effectif des admis boursiers néo bacheliers',
#  '41_Effectif des admis néo bacheliers',
#  '42_Effectif des admis néo bacheliers généraux',
#  '43_Effectif des admis néo bacheliers technologiques',
#  '44_Effectif des admis néo bacheliers professionnels',
#  '45_Effectif des autres candidats admis',
#  '46_Dont effectif des admis néo bacheliers sans information sur la mention au bac',
#  '47_Dont effectif des admis néo bacheliers sans mention au bac',
#  '48_Dont effectif des admis néo bacheliers avec mention Assez Bien au bac',
#  '49_Dont effectif des admis néo bacheliers avec mention Bien au bac',
#  '50_Dont effectif des admis néo bacheliers avec mention Très Bien au bac',
#  '51_Effectif des admis néo bacheliers généraux ayant eu une mention au bac',
#  '52_Effectif des admis néo bacheliers technologiques ayant eu une mention au bac',
#  '53_Effectif des admis néo bacheliers professionnels ayant eu une mention au bac',
#  '54_tri',
#  "55_Dont effectif des admis ayant reçu leur proposition d’admission à l'ouverture de la procédure principale",
#  '56_Dont effectif des admis ayant reçu leur proposition d’admission avant le baccalauréat',
#  '57_Dont effectif des admis ayant reçu leur proposition d’admission avant la fin de la procédure principale',
#  '58_Sélectivité',
#  '59_Filière de formation détaillée.1',
#  '60_Effectif des candidats en terminale générale ayant reçu une proposition d’admission de la part de l’établissement',
#  '61_Dont effectif des candidats boursiers en terminale générale ayant reçu une proposition d’admission de la part de l’établissement',
#  '62_Effectif des candidats en terminale technologique ayant reçu une proposition d’admission de la part de l’établissement',
#  '63_Dont effectif des candidats boursiers en terminale technologique ayant reçu une proposition d’admission de la part de l’établissement',
#  '64_Effectif des candidats en terminale professionnelle ayant reçu une proposition d’admission de la part de l’établissement',
#  '65_Dont effectif des candidats boursiers en terminale générale professionnelle ayant reçu une proposition d’admission de la part de l’établissement',
#  '66_Effectif des autres candidats ayant reçu une proposition d’admission de la part de l’établissement',
#  '67_Regroupement 1 effectué par les formations pour les classements',
#  '68_Rang du dernier appelé du groupe 1',
#  '69_Regroupement 2 effectué par les formations pour les classements',
#  '70_Rang du dernier appelé du groupe 2',
#  '71_Regroupement 3 effectué par les formations pour les classements',
#  '72_Rang du dernier appelé du groupe 3',
#  '73_Regroupement 4 effectué par les formations pour les classements',
#  '74_Rang du dernier appelé du groupe 4',
#  '75_Regroupement 5 effectué par les formations pour les classements',
#  '76_Rang du dernier appelé du groupe 5',
#  '77_Indicateur Parcoursup du taux d’accès des candidats ayant postulé à la formation (ratio entre le dernier appelé et le dernier classé)',
#  '78_Dont taux d’accès des candidats ayant un bac professionnel ayant postulé à la formation',
#  '79_Dont taux d’accès des candidats ayant un bac général ayant postulé à la formation',
#  '80_Dont taux d’accès des candidats ayant un bac technologique ayant postulé à la formation',
#  '81_COD_AFF_FORM',
#  '82_Filière de formation.1',
#  '83_Filière de formation détaillée bis',
#  "84_Concours communs et banque d'épreuves",
#  '85_Dont effectif des admis néo bacheliers avec mention Très Bien avec félicitations au bac',
#  '86_list_com',
#  '87_Taux d’accès des candidats ayant postulé à la formation (ratio entre le dernier appelé et le nombre vœux PP)',
#  '88_cod_aff_form',
#  '89_Taux d’accès',
#  '90_Académie de l’établissement']

# %%
len(voeux['59_Filière de formation détaillée.1'].unique())
# Out:
# 518

# %%
df = pd.DataFrame(dim_admissions['Formation'].unique())

#df.to_excel("Archives/col_dim_adm.xlsx", index= False)

df2 = pd.DataFrame(voeux['2_Filière de formation très agrégée'].unique())

df2.to_excel("Archives/col_voeux.xlsx", index= False)
