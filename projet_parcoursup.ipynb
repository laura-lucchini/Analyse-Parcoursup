# %% [markdown]
# ## **Projet Analyse Parcoursup**

# %% [markdown]
# ### __Analyse sous 3 axes__:
#
# -  Cartographie des formations Parcoursup (période 2020 à 2026)
# -  Vœux de poursuite d'études et de réorientation dans l'enseignement supérieur et réponses des établissements entre 2018 et 2025
# -  Propositions d'admission dans l'enseignement supérieur des élèves de terminale diplômés du baccalauréat général selon leurs enseignements de spécialité

# %% [markdown]
# Sources des données:
#
# https://data.enseignementsup-recherche.gouv.fr/explore/dataset/fr-esr-cartographie_formations_parcoursup/autres_jeux/?disjunctive.tf&disjunctive.nm&disjunctive.fl&disjunctive.nmc&disjunctive.amg

# %%
#Configuration de l'environnement:

import pandas as pd
import numpy as np

# %%
# configuration des options d'affichage

#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

pd.reset_option('display.max_columns')
pd.reset_option('display.max_rows')

# %% [markdown]
# ### Cartographie des formations Parcoursup (période 2020 à 2026)

# %%
carto = pd.read_parquet("sources_brutes/fr-esr-cartographie_formations_parcoursup.parquet")

carto.head(1)
# Out:
#   annee  etab_uai                                           etab_nom       tc  \
# 0  2026  0632084Y  Université Clermont Auvergne (Clermont-Ferrand...  Publics
#
#                         tf                                                 nm  \
# 0  Etudes de santé,Licence  Licence - Parcours d'Accès Spécifique Santé (P...
#
#                                               fl   app   int  \
# 0  L1 - Parcours d'Accès Spécifique Santé (PASS)  None  None
#
#                                                  amg  ...  \
# 0  Enseignement partiellement à distance,Formatio...  ...
#
#                                              dataviz           etab_url  \
# 0  https://data.enseignementsup-recherche.gouv.fr...  http://www.uca.fr
#
#                                             etab_gps   nmc    gta    gti  \
# 0  b'\x01\x01\x00\x00\x00JF\xce\xc2\x9e\xb6\x08@S...  PASS  26631  26629
#
#   etablissement_id_paysage composante_id_paysage   rnd code_formation
# 0                    K4lR3                  None  5660           2047
#
# [1 rows x 25 columns]

# %%
col = pd.DataFrame(carto.columns)

col
# Out:
#                            0
# 0                      annee
# 1                   etab_uai
# 2                   etab_nom
# 3                         tc
# 4                         tf
# 5                         nm
# 6                         fl
# 7                        app
# 8                        int
# 9                        amg
# 10                       aut
# 11                    region
# 12               departement
# 13                   commune
# 14                     fiche
# 15                   dataviz
# 16                  etab_url
# 17                  etab_gps
# 18                       nmc
# 19                       gta
# 20                       gti
# 21  etablissement_id_paysage
# 22     composante_id_paysage
# 23                       rnd
# 24            code_formation

# %%
#Renommage des colonnes

colonnes = {
    'etab_uai':'Identifiant Etablissement ',
    'etab_nom':'nom de l établissement',
    'tc':'Type d établissement',
    'tf':'Type de formation',
    'nm':'Nom de la formation',
    'fl':'Mentions Spécialités',
    'app':'Apprentissage',
    'int':'Internat',
    'amg':'Aménagement',
    'region':'Région',
    'departement':'Département',
    'commune':'Commune',
    'fiche':'Lien vers la fiche formation',
    'dataviz':'Lien vers les données statistiques',
    'etab_url':'Site internet de l établissement',
    'nmc':'Nom court de la formation',
    'gta':'GTA   Gestion des Désistements en Phase d Admission',
    'gti':'GTI   Groupe de Traitement des Inscriptions',
    'rnd':'Rang du dernier candidat appelé'
}

carto = carto.rename(columns=colonnes)
carto.head(1)
# Out:
#   annee Identifiant Etablissement   \
# 0  2026                   0632084Y
#
#                               nom de l établissement Type d établissement  \
# 0  Université Clermont Auvergne (Clermont-Ferrand...              Publics
#
#          Type de formation                                Nom de la formation  \
# 0  Etudes de santé,Licence  Licence - Parcours d'Accès Spécifique Santé (P...
#
#                             Mentions Spécialités Apprentissage Internat  \
# 0  L1 - Parcours d'Accès Spécifique Santé (PASS)          None     None
#
#                                          Aménagement  ...  \
# 0  Enseignement partiellement à distance,Formatio...  ...
#
#                   Lien vers les données statistiques  \
# 0  https://data.enseignementsup-recherche.gouv.fr...
#
#   Site internet de l établissement  \
# 0                http://www.uca.fr
#
#                                             etab_gps  \
# 0  b'\x01\x01\x00\x00\x00JF\xce\xc2\x9e\xb6\x08@S...
#
#   Nom court de la formation  \
# 0                      PASS
#
#   GTA   Gestion des Désistements en Phase d Admission  \
# 0                                              26631
#
#   GTI   Groupe de Traitement des Inscriptions etablissement_id_paysage  \
# 0                                       26629                    K4lR3
#
#   composante_id_paysage Rang du dernier candidat appelé code_formation
# 0                  None                            5660           2047
#
# [1 rows x 25 columns]

# %%
carto.describe(include="all")
# Out:
#          annee Identifiant Etablissement     nom de l établissement  \
# count   155912                     155912                    155912
# unique       7                       7597                     11590
# top       2025                   0673021V  Université de Lille (59)
# freq     25827                        684                       862
#
#        Type d établissement  Type de formation  \
# count                155912             155912
# unique                    6                 85
# top                 Publics  BTS - BTSA - BTSM
# freq                  94825              80919
#
#                                       Nom de la formation  \
# count                                              155912
# unique                                              11433
# top     BTS - Services - Management Commercial Opérati...
# freq                                                 5636
#
#                             Mentions Spécialités                Apprentissage  \
# count                                     155912                        59033
# unique                                      1897                            1
# top     BTS - Management Commercial Opérationnel  Formations en apprentissage
# freq                                        8108                        59033
#
#                                                  Internat  \
# count                                                5216
# unique                                                  3
# top     Etablissements avec internat pour filles et ga...
# freq                                                 5040
#
#                        Aménagement  ...  \
# count                       155912  ...
# unique                          24  ...
# top     Enseignement en présentiel  ...
# freq                        105087  ...
#
#                        Lien vers les données statistiques  \
# count                                               90185
# unique                                              15663
# top     https://data.enseignementsup-recherche.gouv.fr...
# freq                                                    7
#
#        Site internet de l établissement  \
# count                            154787
# unique                             8650
# top       http://formations.univ-amu.fr
# freq                               1004
#
#                                                  etab_gps  \
# count                                              155912
# unique                                              11507
# top     b'\x01\x01\x00\x00\x00\x06\r\xfd\x13\\,\x03@#J...
# freq                                                  612
#
#        Nom court de la formation  \
# count                     155912
# unique                      1677
# top                  BTS-MCO-App
# freq                        4889
#
#        GTA   Gestion des Désistements en Phase d Admission  \
# count                                              155912
# unique                                              34048
# top                                                  2480
# freq                                                    7
#
#        GTI   Groupe de Traitement des Inscriptions etablissement_id_paysage  \
# count                                       155912                    49771
# unique                                       30676                      505
# top                                            166                    xJdyB
# freq                                           486                     1277
#
#        composante_id_paysage Rang du dernier candidat appelé code_formation
# count                   1846                          138922         138922
# unique                   106                           32313           1291
# top                    Ib4aA                               0          11423
# freq                      65                             104           5374
#
# [4 rows x 25 columns]

# %%
valeurs_manquantes = pd.DataFrame({'valeurs manquantes' : carto.isna().sum()})
valeurs_manquantes = valeurs_manquantes.sort_values(by= 'valeurs manquantes', ascending = False)
valeurs_manquantes
# Out:
#                                                     valeurs manquantes
# composante_id_paysage                                           154066
# Internat                                                        150696
# aut                                                             129635
# etablissement_id_paysage                                        106141
# Apprentissage                                                    96879
# Lien vers les données statistiques                               65727
# Lien vers la fiche formation                                     36429
# code_formation                                                   16990
# Rang du dernier candidat appelé                                  16990
# Site internet de l établissement                                  1125
# Commune                                                            773
# Département                                                        296
# Région                                                             296
# nom de l établissement                                               0
# Identifiant Etablissement                                            0
# annee                                                                0
# Type de formation                                                    0
# Nom de la formation                                                  0
# Mentions Spécialités                                                 0
# Type d établissement                                                 0
# Aménagement                                                          0
# GTI   Groupe de Traitement des Inscriptions                          0
# GTA   Gestion des Désistements en Phase d Admis...                   0
# Nom court de la formation                                            0
# etab_gps                                                             0

# %%
region_vide = carto[carto["Région"].isna()]
region_vide
# Out:
#        annee Identifiant Etablissement   \
# 419     2026                   3500067W
# 639     2026                   0763381M
# 641     2026                   0542407Y
# 1095    2026                   1360003P
# 2900    2026                   T171435T
# ...      ...                        ...
# 148236  2020                   9840386X
# 148838  2020                   1090025K
# 149632  2020                   9730279R
# 154185  2020                   2260003A
# 155866  2020                   1320020E
#
#                                    nom de l établissement  \
# 419     ESSEC Business School - Global BBA - track fra...
# 639     Sciences Po - campus du Havre - Keio Universit...
# 641     Sciences Po - campus de Nancy - Freie Universi...
# 1095    EM Normandie - Programme Grande Ecole - Campus...
# 2900                     EIGSI Casablanca (Maroc) (Maroc)
# ...                                                   ...
# 148236                              Lycée de Papara (987)
# 148838  Université Paris Dauphine - Campus de Francfor...
# 149632                         EGC Guyane (Matoury - 973)
# 154185  ESSEC Business School - Campus de Singapour (S...
# 155866  Ecole de management de Normandie - Campus d'Ox...
#
#                         Type d établissement  \
# 419     Privés en contrat avec l’Etat / EESC
# 639                                  Publics
# 641                                  Publics
# 1095    Privés en contrat avec l’Etat / EESC
# 2900    Privés en contrat avec l’Etat / EESC
# ...                                      ...
# 148236                               Publics
# 148838                               Publics
# 149632                                Privés
# 154185                                Privés
# 155866                                Privés
#
#                                         Type de formation  \
# 419     Formations des écoles de commerce et de manage...
# 639           Sciences Po - Instituts d'études politiques
# 641           Sciences Po - Instituts d'études politiques
# 1095    Formations des écoles de commerce et de manage...
# 2900                   Formations des écoles d'ingénieurs
# ...                                                   ...
# 148236                                  BTS - BTSA - BTSM
# 148838                                  Licence sélective
# 149632  Formations des écoles de commerce et de manage...
# 154185  Formations des écoles de commerce et de manage...
# 155866  Formations des écoles de commerce et de manage...
#
#                                       Nom de la formation  \
# 419     Formation des écoles de commerce et de managem...
# 639     Sciences Po / Instituts d'études politiques - ...
# 641     Double diplôme Sciences Po (Programme européen...
# 1095    Formation des écoles de commerce et de managem...
# 2900    Formation d'ingénieur Bac + 5 - Bac série géné...
# ...                                                   ...
# 148236                BTS - Production - Electrotechnique
# 148838  Formation valant grade de licence - Sciences d...
# 149632  Formation des écoles de commerce et de managem...
# 154185  Formation des écoles de commerce et de managem...
# 155866  Formation des écoles de commerce et de managem...
#
#                                      Mentions Spécialités Apprentissage  \
# 419     Formation des écoles de commerce et de managem...          None
# 639     Sciences Po / Instituts d'études politiques - ...          None
# 641     Sciences Po / Instituts d'études politiques - ...          None
# 1095    Formation des écoles de commerce et de managem...          None
# 2900                        Formation d'ingénieur Bac + 5          None
# ...                                                   ...           ...
# 148236                             BTS - Electrotechnique          None
# 148838                  Formation valant grade de licence          None
# 149632  Formation des écoles de commerce et de managem...          None
# 154185  Formation des écoles de commerce et de managem...          None
# 155866  Formation des écoles de commerce et de managem...          None
#
#        Internat                                        Aménagement  ...  \
# 419        None                         Enseignement en présentiel  ...
# 639        None  Enseignement en présentiel,Formations avec amé...  ...
# 641        None  Enseignement en présentiel,Formations avec amé...  ...
# 1095       None                         Enseignement en présentiel  ...
# 2900       None  Enseignement en présentiel,Formations avec amé...  ...
# ...         ...                                                ...  ...
# 148236     None                         Enseignement en présentiel  ...
# 148838     None                         Enseignement en présentiel  ...
# 149632     None                         Enseignement en présentiel  ...
# 154185     None                         Enseignement en présentiel  ...
# 155866     None                         Enseignement en présentiel  ...
#
#                        Lien vers les données statistiques  \
# 419     https://data.enseignementsup-recherche.gouv.fr...
# 639                                                  None
# 641                                                  None
# 1095    https://data.enseignementsup-recherche.gouv.fr...
# 2900                                                 None
# ...                                                   ...
# 148236  https://data.enseignementsup-recherche.gouv.fr...
# 148838  https://data.enseignementsup-recherche.gouv.fr...
# 149632  https://data.enseignementsup-recherche.gouv.fr...
# 154185  https://data.enseignementsup-recherche.gouv.fr...
# 155866  https://data.enseignementsup-recherche.gouv.fr...
#
#                          Site internet de l établissement  \
# 419                https://www.essec.edu/fr/campus/rabat/
# 639                             http://www.sciencespo.fr/
# 641                             http://www.sciencespo.fr/
# 1095                      https://www.em-normandie.com/fr
# 2900                              https://www.eigsica.ma/
# ...                                                   ...
# 148236                         http://www.lyceepapara.com
# 148838                             http://dauphine.psl.eu
# 149632                           http://egc@guyane.cci.fr
# 154185  http://www.essec.edu/fr/programme/global-bba/b...
# 155866                    https://www.em-normandie.com/fr
#
#                                                  etab_gps  \
# 419     b'\x01\x01\x00\x00\x00\xabx#\xf3\xc8\xff\x1a\x...
# 639     b'\x01\x01\x00\x00\x00\x89$z\x19\xc5wa@\x89\x0...
# 641      b'\x01\x01\x00\x00\x00\xcaO\xaa}:\x8e*@oG8-x9J@'
# 1095    b'\x01\x01\x00\x00\x00\xa8\x18\xe7oB\x01\x19\x...
# 2900    b'\x01\x01\x00\x00\x00\xf6\x7f\x0e\xf3\xe5\x85...
# ...                                                   ...
# 148236  b'\x01\x01\x00\x00\x00\xacs\x0c\xc8^\xafb\xc0\...
# 148838  b'\x01\x01\x00\x00\x00\xd0~\xa4\x88\x0c[!@\xca...
# 149632  b'\x01\x01\x00\x00\x00I.\xff!\xfd.J\xc09\xd6\x...
# 154185  b'\x01\x01\x00\x00\x00\xdfO\x8d\x97n\xf2Y@c\x7...
# 155866  b'\x01\x01\x00\x00\x00\x16\x13\x9b\x8fkC\xf4\x...
#
#        Nom court de la formation  \
# 419                      FECM-B4
# 639                     ScPo-Lic
# 641                     ScPo-Lic
# 1095                     FECM-B5
# 2900                     FI-BAC5
# ...                          ...
# 148236            BTS-Electrotec
# 148838                      FVGL
# 149632                   FECM-B3
# 154185                   FECM-B4
# 155866                   FECM-B5
#
#        GTA   Gestion des Désistements en Phase d Admission  \
# 419                                                 31987
# 639                                                 34466
# 641                                                 34475
# 1095                                                39294
# 2900                                                50569
# ...                                                   ...
# 148236                                              13596
# 148838                                              25820
# 149632                                              12047
# 154185                                              28455
# 155866                                              28453
#
#        GTI   Groupe de Traitement des Inscriptions etablissement_id_paysage  \
# 419                                          26102                     None
# 639                                          32570                    u79ZJ
# 641                                          32569                    u79ZJ
# 1095                                         26102                     None
# 2900                                         50563                     None
# ...                                            ...                      ...
# 148236                                       13596                     None
# 148838                                       25820                    C6Ps7
# 149632                                       12047                     None
# 154185                                       26102                     None
# 155866                                       26102                    NAzKJ
#
#        composante_id_paysage Rang du dernier candidat appelé code_formation
# 419                     None                            6628            242
# 639                    4hGhl                            4794            291
# 641                    lp6tu                           19029            291
# 1095                    None                           24821            240
# 2900                    None                            3377            210
# ...                      ...                             ...            ...
# 148236                  None                            None           None
# 148838                  None                            None           None
# 149632                  None                            None           None
# 154185                  None                            None           None
# 155866                 yBIbR                            None           None
#
# [296 rows x 25 columns]

# %%
# gestion des valeurs manquantes, elles correspondent à des campus hors métropole 

carto['Région'] = carto["Région"].fillna("Campus hors métropole")

carto['Département'] = carto["Département"].fillna("Campus hors métropole")

#Suppression des colonnes composante_id_paysage	Internat, aut , etablissement_id_paysage	

col_a_supprimer = ["composante_id_paysage","Internat","aut","etablissement_id_paysage","Lien vers les données statistiques"]

carto = carto.drop(columns=col_a_supprimer)

carto.shape
# Out:
# (155912, 20)

# %%
carto["Rang du dernier candidat appelé"] = carto["Rang du dernier candidat appelé"].fillna(0)

# %%
valeurs_manquantes = pd.DataFrame({'valeurs manquantes' : carto.isna().sum()})
valeurs_manquantes = valeurs_manquantes.sort_values(by= 'valeurs manquantes', ascending = False)
valeurs_manquantes
# Out:
#                                                     valeurs manquantes
# Apprentissage                                                    96879
# Lien vers la fiche formation                                     36429
# code_formation                                                   16990
# Site internet de l établissement                                  1125
# Commune                                                            773
# nom de l établissement                                               0
# Identifiant Etablissement                                            0
# annee                                                                0
# Type d établissement                                                 0
# Mentions Spécialités                                                 0
# Nom de la formation                                                  0
# Type de formation                                                    0
# Département                                                          0
# Région                                                               0
# Aménagement                                                          0
# etab_gps                                                             0
# Nom court de la formation                                            0
# GTA   Gestion des Désistements en Phase d Admis...                   0
# GTI   Groupe de Traitement des Inscriptions                          0
# Rang du dernier candidat appelé                                      0

# %%
carto.dtypes
# Out:
# annee                                                  object
# Identifiant Etablissement                              object
# nom de l établissement                                 object
# Type d établissement                                   object
# Type de formation                                      object
# Nom de la formation                                    object
# Mentions Spécialités                                   object
# Apprentissage                                          object
# Aménagement                                            object
# Région                                                 object
# Département                                            object
# Commune                                                object
# Lien vers la fiche formation                           object
# Site internet de l établissement                       object
# etab_gps                                               object
# Nom court de la formation                              object
# GTA   Gestion des Désistements en Phase d Admission    object
# GTI   Groupe de Traitement des Inscriptions            object
# Rang du dernier candidat appelé                        object
# code_formation                                         object
# dtype: object

# %%
carto["Rang du dernier candidat appelé"] = carto["Rang du dernier candidat appelé"].astype(int)
carto.dtypes
# Out:
# annee                                                  object
# Identifiant Etablissement                              object
# nom de l établissement                                 object
# Type d établissement                                   object
# Type de formation                                      object
# Nom de la formation                                    object
# Mentions Spécialités                                   object
# Apprentissage                                          object
# Aménagement                                            object
# Région                                                 object
# Département                                            object
# Commune                                                object
# Lien vers la fiche formation                           object
# Site internet de l établissement                       object
# etab_gps                                               object
# Nom court de la formation                              object
# GTA   Gestion des Désistements en Phase d Admission    object
# GTI   Groupe de Traitement des Inscriptions            object
# Rang du dernier candidat appelé                         int64
# code_formation                                         object
# dtype: object

# %%
carto.to_csv("sources_clean_powerBI/Cartographie_formations_pbi", index=False)

print("le fichier est prêt à être intégré dans PowerBI")
# Out:
# le fichier est prêt à être intégré dans PowerBI

# %% [markdown]
# ### Vœux de poursuite d'études et de réorientation dans l'enseignement supérieur et réponses des établissements entre 2018 et 2025

# %%
periode = ["2018","2019","2020","2021","2022","2023","2024","2025"]

dataframes = []

for i in periode:
    fichier_parquet = "sources_brutes/fr-esr-parcoursup_"+i+".parquet"
    df = pd.read_parquet(fichier_parquet)
    dataframes.append(df)


for idx, df in enumerate(dataframes):
    print(f"\n--- Fichier {periode[idx]} ---")
    display(df.head(1))
# Out:
# --- Fichier 2018 ---
#   session   cod_uai                    g_ea_lib_vx dep dep_lib  \
# 0    2018  0692437Z  Université Jean Moulin Lyon 3  69   Rhône
#
#         region_etab_aff acad_mies     fili                form_lib_voe_acc  \
# 0  Auvergne-Rhône-Alpes      Lyon  Licence  Licence - Arts-lettres-langues
#
#   regr_forma  ... pct_ab pct_b pct_tb pct_bg  pct_bg_mention  pct_bt  \
# 0       None  ...    0.0   0.0    0.0  100.0             0.0     0.0
#
#    pct_bt_mention  pct_bp  pct_bp_mention            tri
# 0             0.0     0.0             0.0  1_universités
#
# [1 rows x 85 columns]
# --- Fichier 2019 ---
#   session contrat_etab   cod_uai          g_ea_lib_vx dep   dep_lib  \
# 0    2019        Privé  0783720V  ESEO Paris - Vélizy  78  Yvelines
#
#   region_etab_aff   acad_mies             fili         form_lib_voe_acc  ...  \
# 0   Ile-de-France  Versailles  Autre formation  Formations d'ingénieurs  ...
#
#       pct_ab     pct_b    pct_tb pct_bg pct_bg_mention  pct_bt  \
# 0  33.328125  7.142578  2.380859  100.0      42.851562     0.0
#
#    pct_bt_mention  pct_bp  pct_bp_mention                  tri
# 0             0.0     0.0             0.0  3_Autres formations
#
# [1 rows x 92 columns]
# --- Fichier 2020 ---
#   session                      contrat_etab   cod_uai  \
# 0    2020  Privé sous contrat d'association  0754784T
#
#                             g_ea_lib_vx dep dep_lib region_etab_aff acad_mies  \
# 0  Ecole de service social de la CRAMIF  75   Paris   Ile-de-France     Paris
#
#            select_form  fili  ... lib_grp4 ran_grp4 lib_grp5 ran_grp5  \
# 0  formation selective  EFTS  ...     None     None     None     None
#
#   taux_adm_psup taux_adm_psup_pro taux_adm_psup_gen  taux_adm_psup_techno  \
# 0          57.0              42.0              31.0                  19.0
#
#                    tri  cod_aff_form
# 0  3_Autres formations         23450
#
# [1 rows x 115 columns]
# --- Fichier 2021 ---
#   session                      contrat_etab   cod_uai  g_ea_lib_vx dep  \
# 0    2021  Privé sous contrat d'association  0932019P  ESIEE Paris  93
#
#              dep_lib region_etab_aff acad_mies      ville_etab  \
# 0  Seine-Saint-Denis   Ile-de-France   Créteil  Noisy-le-Grand
#
#            select_form  ...                                list_com  \
# 0  formation sélective  ...  Liste d'appel propre à cette formation
#
#                    tri cod_aff_form  \
# 0  3_Autres formations           94
#
#                                       lien_form_psup taux_adm_psup  \
# 0  https://dossier.parcoursup.fr/Candidat/carte?g...          77.0
#
#   taux_adm_psup_gen taux_adm_psup_techno taux_adm_psup_pro  \
# 0             100.0                  0.0               0.0
#
#    etablissement_id_paysage  composante_id_paysage
# 0                     mFZJs                   None
#
# [1 rows x 118 columns]
# --- Fichier 2022 ---
#   session contrat_etab   cod_uai              g_ea_lib_vx dep         dep_lib  \
# 0    2022       Public  0770926N  Lycée Francois Couperin  77  Seine-et-Marne
#
#   region_etab_aff acad_mies     ville_etab  \
# 0   Ile-de-France   Créteil  Fontainebleau
#
#                                   lib_for_voe_ins  ...       tri cod_aff_form  \
# 0  CPGE - ECG -  - Mathématiques appliquées + ESH  ...  2_Lycées        31292
#
#   detail_forma2                                     lien_form_psup  \
# 0          None  https://dossier.parcoursup.fr/Candidats/public...
#
#   taux_acces_ens part_acces_gen part_acces_tec  part_acces_pro  \
# 0           80.0          100.0            0.0             0.0
#
#    etablissement_id_paysage  composante_id_paysage
# 0                      None                   None
#
# [1 rows x 118 columns]
# --- Fichier 2023 ---
#   session                      contrat_etab   cod_uai        g_ea_lib_vx dep  \
# 0    2023  Privé sous contrat d'association  0031041R  Lycée Anna Rodier  03
#
#   dep_lib       region_etab_aff         acad_mies ville_etab  \
# 0  Allier  Auvergne-Rhône-Alpes  Clermont-Ferrand    Moulins
#
#                       lib_for_voe_ins  ...       tri cod_aff_form  \
# 0  BTS - Services - Gestion de la PME  ...  2_Lycées         2151
#
#   detail_forma2                                     lien_form_psup  \
# 0          None  https://dossier.parcoursup.fr/Candidats/public...
#
#   taux_acces_ens part_acces_gen part_acces_tec  part_acces_pro  \
# 0           77.0           25.0           44.0            31.0
#
#    etablissement_id_paysage  composante_id_paysage
# 0                      None                   None
#
# [1 rows x 118 columns]
# --- Fichier 2024 ---
#   session contrat_etab   cod_uai            g_ea_lib_vx dep       dep_lib  \
# 0    2024       Public  0870669E  Université de Limoges  87  Haute-Vienne
#
#       region_etab_aff acad_mies ville_etab  \
# 0  Nouvelle Aquitaine   Limoges    Limoges
#
#                            lib_for_voe_ins  ...            tri cod_aff_form  \
# 0  Licence - Portail Droit - Droit Limoges  ...  1_universités        10718
#
#   detail_forma2                                     lien_form_psup  \
# 0          None  https://dossier.parcoursup.fr/Candidats/public...
#
#   taux_acces_ens part_acces_gen part_acces_tec  part_acces_pro  \
# 0            100           81.0           15.0             4.0
#
#    etablissement_id_paysage  composante_id_paysage
# 0                     nkbwh                   None
#
# [1 rows x 118 columns]
# --- Fichier 2025 ---
#   session contrat_etab   cod_uai            g_ea_lib_vx dep dep_lib  \
# 0    2025       Public  0755976N  Université Paris Cité  75   Paris
#
#   region_etab_aff acad_mies                 ville_etab  \
# 0   Ile-de-France     Paris  Paris  6e  Arrondissement
#
#                                      lib_for_voe_ins  ...            tri  \
# 0  Licence - Parcours d'Accès Spécifique Santé (P...  ...  1_universités
#
#   cod_aff_form detail_forma2  \
# 0        28097          None
#
#                                       lien_form_psup taux_acces_ens  \
# 0  https://dossierappel.parcoursup.fr/Candidats/p...             27
#
#   part_acces_gen part_acces_tec  part_acces_pro  etablissement_id_paysage  \
# 0             99              1               0                      None
#
#    composante_id_paysage
# 0                   None
#
# [1 rows x 118 columns]

# %%
# Liste des années
periode = ["2018", "2019", "2020", "2021", "2022", "2023", "2024", "2025"]

# Charger les DataFrames et stocker les colonnes dans l'ordre initial
dataframes = []
colonnes_par_annee = {}
for annee in periode:
    fichier_parquet = f"sources_brutes/fr-esr-parcoursup_{annee}.parquet"
    df = pd.read_parquet(fichier_parquet)
    colonnes_par_annee[annee] = df.columns.tolist()  # Conserver l'ordre initial
    dataframes.append(df)

# Lister toutes les colonnes uniques dans l'ordre d'apparition
toutes_colonnes = []
for annee in periode:
    for colonne in colonnes_par_annee[annee]:
        if colonne not in toutes_colonnes:
            toutes_colonnes.append(colonne)

# Ajouter les colonnes manquantes à chaque DataFrame (remplies de NaN)
for i, annee in enumerate(periode):
    df = dataframes[i]
    for colonne in toutes_colonnes:
        if colonne not in df.columns:
            df[colonne] = np.nan  
    # Réorganiser les colonnes dans l'ordre de toutes_colonnes
    df = df[toutes_colonnes]
    dataframes[i] = df

# Concaténer les DataFrames
voeux = pd.concat(dataframes, ignore_index=True)

# Afficher un aperçu du résultat
print("Aperçu du DataFrame concaténé :")
print(f"le DataFrame concaténé contient {len(voeux)} lignes")
display(voeux.head())
# Out:
# Aperçu du DataFrame concaténé :
# le DataFrame concaténé contient 104274 lignes
#   session   cod_uai                           g_ea_lib_vx dep  \
# 0    2018  0692437Z         Université Jean Moulin Lyon 3  69
# 1    2018  0751717J  Université Paris 1 Panthéon Sorbonne  75
# 2    2018  0931827F                    Université Paris 8  93
# 3    2018  0921204J             Université Paris Nanterre  92
# 4    2018  0921204J             Université Paris Nanterre  92
#
#              dep_lib       region_etab_aff   acad_mies             fili  \
# 0              Rhône  Auvergne-Rhône-Alpes        Lyon          Licence
# 1              Paris         Ile-de-France       Paris  Autre formation
# 2  Seine-Saint-Denis         Ile-de-France     Créteil          Licence
# 3     Hauts-de-Seine         Ile-de-France  Versailles          Licence
# 4     Hauts-de-Seine         Ile-de-France  Versailles          Licence
#
#                           form_lib_voe_acc regr_forma  ... detail_forma2  \
# 0           Licence - Arts-lettres-langues       None  ...           NaN
# 1                                       DU       None  ...           NaN
# 2  Licence - Sciences humaines et sociales       None  ...           NaN
# 3           Licence - Arts-lettres-langues       None  ...           NaN
# 4           Licence - Arts-lettres-langues       None  ...           NaN
#
#   acc_tbf pct_tbf list_com  etablissement_id_paysage  composante_id_paysage  \
# 0     NaN     NaN      NaN                       NaN                    NaN
# 1     NaN     NaN      NaN                       NaN                    NaN
# 2     NaN     NaN      NaN                       NaN                    NaN
# 3     NaN     NaN      NaN                       NaN                    NaN
# 4     NaN     NaN      NaN                       NaN                    NaN
#
#    taux_acces_ens  part_acces_gen  part_acces_tec  part_acces_pro
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
# [5 rows x 128 columns]

# %% [markdown]
# ### Propositions d'admission dans l'enseignement supérieur des élèves de terminale diplômés du baccalauréat général selon leurs enseignements de spécialité
